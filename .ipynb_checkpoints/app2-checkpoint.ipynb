# %%
import matplotlib.pyplot as plt

# %%
from google_play_scraper import Sort, reviews

def getReviews(count):
    result, _ = reviews(
        'com.linkdokter.halodoc.android',
        lang='id',
        country='id',
        sort=Sort.MOST_RELEVANT,
        count=count,
    )
    return result

reviews = getReviews(5000)
reviews
# Out:
# [{'reviewId': '4f9da834-8ef2-431f-9f0f-81c3457a9125',
#   'userName': 'wafi izzudien',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClbvmpXmXJ4I6rIbUw0Otp6fzKXcKhLYXT5-R08',
#   'content': 'Di antar banyaknya rating bintang 1, belum tentu aplikasi itu jelek dan tidak layak dipakai, syukur deh Halodoc mempertimbangkan semua ulasan dan masukkan di aplikasinya, jadi saya rasa aplikasi ini udah semaikin baik. Terima kasih Halodoc',
#   'score': 5,
#   'thumbsUpCount': 14,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 14, 17, 45, 35),
#   'replyContent': 'Hai wafi izzudien! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 14, 18, 40, 50)},
#  {'reviewId': 'f310241e-f30b-4a27-8011-94f0ccdb4615',
#   'userName': 'Suga Dillah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCksDaR3IwVoS1mq_u27baB8beYkL276WF3XCLjLOQ',
#   'content': 'Sengaja daftar vaksin di halodok biar cepet. Dibilang datang 30 menit lebih awal Pas sampe puskemas kebayoran lama tetep harus antri. Nunggu 2 jam ngaret bener. Emangnya pihak halodok sama puskesnya gak kordinasi lagi. Terus ngapain daftar di app halodok kalo ujungnya ujungnya harus antri juga sama yg gak daftar di aplikasi.',
#   'score': 1,
#   'thumbsUpCount': 12,
#   'reviewCreatedVersion': '15.700',
#   'at': datetime.datetime(2023, 1, 13, 13, 55, 23),
#   'replyContent': 'Hai Suga Dillah! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu agar dapat kami bantu lebih lanjut. Mohon kesediannya untuk menghubungi tim CS kami di menu bantuan aplikasi Halodoc agar dapat kami bantu lebih lanjut. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2023, 1, 13, 14, 34, 11)},
#  {'reviewId': '3c3c832d-a2e5-4b5d-b17c-621b385405b3',
#   'userName': '002 Syifaul Amrodi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCk3-B6Nl6MlkRqfsHcrUy_Pvksg_cv5ptK-x5BvVQ',
#   'content': 'Saya kesel banget sama aplikasi ini. Saya udah keluarin uang tapi pas konsultasi dibales sama dokternya juga engga. Dana ngga bisa direfund lagi. Kalau spt ini yg dirugikan pasien. Tolong lah perbaiki sistemnya dulu. Seharusnya pembayaran boleh lah di awal. tapi uang masih dicekal, nanti baru uang bisa dilepas kalau dokter dan pasien sama" klik konfirmasi selesai. Kalau dokter ga ngeklik selesai, pasien boleh komplain harusnya. karena artinya dokternya gak aktif, atau ninggalin.',
#   'score': 1,
#   'thumbsUpCount': 20,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 8, 23, 26, 37),
#   'replyContent': 'Hai Syifaul Amrodi! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu agar dapat kami bantu lebih lanjut. Mohon kesediannya untuk menghubungi tim CS kami di menu bantuan aplikasi Halodoc agar dapat kami bantu lebih lanjut. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2023, 1, 8, 23, 31, 37)},
#  {'reviewId': '44ade954-5703-45e5-9472-6675b6fb113e',
#   'userName': 'Ariaya Nur Anggarani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5WYXwUa_E-_8_BzM5utTPgwsYGyhSajdn7rfVXaQ=mo',
#   'content': 'Kalau dokternya tidak standby tolong jangan ditampilkan, saya kira kalau dibatalkan oleh system bakal ke refund otomatis ternyata tidak dan juga harusnya ada rate buat dokter yg suka batal itu biar bisa langsung di rate 1, masa tidak sekali dua kali selalu dibatalkan oleh sistem giliran inget kalau belum di refund ternyata gabisa di refund kalo sudah lwt dari 7 hari, ga semua orang selalu mantau saldo nya sudah ke refund atau belum',
#   'score': 1,
#   'thumbsUpCount': 65,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 21, 10, 13, 32),
#   'replyContent': 'Hai Ariaya Nur Anggarani! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 11, 21, 11, 5, 3)},
#  {'reviewId': 'fda13ade-581f-41af-a505-2222138ac103',
#   'userName': 'Kuskus 01',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCm7PfHJFMx_3qoVoVmvNWs80wMFjz6Gp5Odk5zh',
#   'content': "Hallo HALODOC. Kenapa pesanan saya tidak sampai? Saya pesan dari tanggal 9 november sampai sekarang tanggal 19 november status nya masih 'terkonfirmasi' tidak ada perubahan sedikitpun. Kalaupun mau dibatalkan sudah tidak bisa dan tidak ada pilihan nya. Tolong dong konfirmasi pesanan saya",
#   'score': 3,
#   'thumbsUpCount': 32,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 19, 8, 32, 16),
#   'replyContent': 'Hai Kuskus 01! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 11, 19, 8, 43, 22)},
#  {'reviewId': '97835135-8c26-44a4-af0f-5c35042998d3',
#   'userName': 'pras dika',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCnQPADXO6Ik__naEhREbyBdnfMbyqGTGCZALAvh',
#   'content': 'Tidak synergy antar aplikasi seperti gojek sehingga pelanggan yang ingin pesan di apotik yang sudah terlanjur bayar tidak dapat pesanan lama. Lumayan uang 100 ribu hanya di ampasin sama cs halodoc. Tolong tingkatkan lagi aplikasi agar berguna .',
#   'score': 1,
#   'thumbsUpCount': 46,
#   'reviewCreatedVersion': '15.700',
#   'at': datetime.datetime(2022, 12, 25, 17, 17, 31),
#   'replyContent': 'Hai pras dika! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 25, 17, 23, 37)},
#  {'reviewId': '9be0bce0-3352-4228-8b4a-e38b7744f50f',
#   'userName': 'Setiawan My Name',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp7XlEW6CMYnC0ozRDphjIdZ_kF2MmP7JiPnECpp=mo',
#   'content': 'Mana nih depelovernya saya mau komplen masa dari 5 kali konsul itu cuma satu yg sukses yg 4 nya di cancel semua, apa apaan coba uang kita belum di refund juga sampe sekarang yg benar saja. Gw bener2 minta tolong sama lo ya depelover tolong perbaiki sistem di aplikasimu jadi gini gw kasih saran tolong jangan langsung saldo orang dipotong sebelum bener2 bisa konsul/terhubung, nah ketika sudah bisa berhasil konsul dgn dokternya baru dah saldo itu bisa terpotong. Sistem buruk cuma bisa bikin app',
#   'score': 1,
#   'thumbsUpCount': 73,
#   'reviewCreatedVersion': '15.401',
#   'at': datetime.datetime(2022, 12, 13, 6, 20, 32),
#   'replyContent': 'Hai Setiawan My Name! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu agar dapat kami bantu lebih lanjut. Mohon kesediannya untuk menghubungi tim CS kami di menu bantuan aplikasi Halodoc agar dapat kami bantu lebih lanjut. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2022, 12, 13, 6, 37, 51)},
#  {'reviewId': '300497f5-a396-4bb2-bbac-72c8b16451d6',
#   'userName': 'Endah Krisna',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmj7joPjJdYH3KJwktNLKaEe6kS_qcm7YazZWfY_Q',
#   'content': 'Ongkirnya cukup Mahal juga ya😌 ditambah tampilan ux dibagian keranjang kurang menarik karena harus menambahkan alamat berulang-ulang ketika memesan obat. Oh iya, sama kenapa gak Ada keterangan lokasi pemesanan obat diapp. Jadi pesan obat banyak tapi lokasinya beda-beda ongkirnya double',
#   'score': 4,
#   'thumbsUpCount': 30,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 13, 11, 8, 31),
#   'replyContent': 'Hai Endah Krisna! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 11, 13, 11, 6, 14)},
#  {'reviewId': '8a9329bc-58a6-4daa-8d96-cc9c4f71bfca',
#   'userName': 'Noviani Kurniati',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp6RvofrnjYt48iI94_RC2oA2nnybFuEGYoJtIjK=mo',
#   'content': 'Sangat membantu sekali, dan dibantu sampai semuanya tuntas, bagus bangett pelayanannya, dikasih rekomendasi terus, dikasih treatment, ga ngebosenin, bahkan masih konsultasi meskipun udah sembuh. Seneng bangetttt sama pelayanannya gabisa berkata-kata lagiiii. Seneng sekaligus sedih karna udah harus mengakhiri konseling',
#   'score': 5,
#   'thumbsUpCount': 51,
#   'reviewCreatedVersion': '15.401',
#   'at': datetime.datetime(2022, 12, 10, 21, 32, 57),
#   'replyContent': 'Hai Noviani Kurniati! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu.',
#   'repliedAt': datetime.datetime(2022, 12, 10, 22, 12, 51)},
#  {'reviewId': 'ca9c1a72-f222-4ec3-b070-1ba22961f288',
#   'userName': 'Sandy Ashari',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCm_nhlt9JV6q-r8srz-ND93X3yIMIOnyH2yPjcM',
#   'content': 'Saya lagi dimalang. hrusnya aplikasi yg akses izin lokasi, bisa deteksi lokasi saya dimana (auto located). Ini enggak, malah lokasi saya di jakarta. & Kebetulan ini diluar kota jadi saya gk cek lagi lokasi saya. Akhirnya saya ikhlaskan uang saya & obatnya untuk drivernya. Harusnya aplikasi ini bisa deteksi lokasi otomatis, tapi ini zonk.',
#   'score': 1,
#   'thumbsUpCount': 30,
#   'reviewCreatedVersion': '15.401',
#   'at': datetime.datetime(2022, 12, 6, 20, 40, 33),
#   'replyContent': 'Hai Sandy Ashari! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor tlp +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 6, 20, 53, 43)},
#  {'reviewId': 'a5bb011b-222e-434d-88d1-ef13141ff178',
#   'userName': 'No name',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp4BaBk24HGSFPw0s2TstZA7585lFevNfBvjNZ09=mo',
#   'content': 'Kenapa pembayaran mesti pake uang elektronik ( gopay, link aja) sama kartu kredit sih ?? Jadi gak bisa lakuin pembayaran dan otomatis gak bisa Konsul. Auto hapus aplikasi 😩',
#   'score': 2,
#   'thumbsUpCount': 24,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 16, 9, 46, 32),
#   'replyContent': 'Hai No name! Mohon maaf atas ketidaknyamanannya. Guna meningkatkan pelayanan Halodoc, maka Halodoc melakukan penyesuaian metode pembayaran. Kamu dapat mencoba direct payment (Gopay, kartu debit, kartu kredit, LinkAja, dan Virtual Account). Apabila ada kendala lain silakan hubungi tim CS kami di menu bantuan aplikasi Halodoc.',
#   'repliedAt': datetime.datetime(2022, 11, 16, 10, 3, 13)},
#  {'reviewId': '655a79b0-9164-4393-9f04-babbcf0a9399',
#   'userName': 'Agus Sulardi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp46Kz7exUGlAPgj98SzE1KLN90qwNE-18UoPGaI=mo',
#   'content': 'Jawaban dari dokternya cukup baik,respone cepat,sangat membantu sekali untuk orang yg khususnya tidak memungkinkan untuk keluar rumah,terima kasih halo doc dan dr steven,mudah2 an resep yg diberikan bisa jadi jalan kesembuhan saya.',
#   'score': 5,
#   'thumbsUpCount': 23,
#   'reviewCreatedVersion': '15.401',
#   'at': datetime.datetime(2022, 12, 10, 14, 2, 58),
#   'replyContent': 'Hai Agus Sulardi! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 10, 14, 18, 51)},
#  {'reviewId': 'f51fc76d-591e-44b2-9aa8-10bf44f579b1',
#   'userName': 'Adiba Qonita Shakila',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClfpSud4AciEQFHvqS8OVe_VKA79knXxSt2AyJG8w',
#   'content': 'Orderan reguler 1 - 3 hari nyampe Udh masuk hari ke 3 barang dikirim juga belom. Mana obat mahal dan obatnya ga boleh putus minumnya. Di telp ke CS mau pembatalan mau pesen ulang biar ubah pengiriman pake instan ga bisa juga. Ga membantu sama sekali. Klo smp terjadi apa2 sm saya saya tuntut halodoc',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 9, 10, 33, 1),
#   'replyContent': 'Hai Adiba Qonita Shakila! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu agar dapat kami bantu lebih lanjut. Mohon kesediannya untuk menghubungi tim CS kami di menu bantuan aplikasi Halodoc agar dapat kami bantu lebih lanjut. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2023, 1, 9, 11, 20, 18)},
#  {'reviewId': 'ad4e87b9-4db7-40e7-8fc1-740c25860025',
#   'userName': 'Agus Munawar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCk-x6LOsTCw1IqWFh_GF295VWSr-KQiznD_TnJjAA',
#   'content': 'Sangat membantu walaupun GPS sering meleset, tapi untuk saat ini ada kendala : Saldo Asuransi masih banyak, tapi saat transaksi saldo Rp.0 di aplikasi Halodoc nya?',
#   'score': 4,
#   'thumbsUpCount': 28,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 14, 22, 23, 2),
#   'replyContent': 'Hai Agus Munawar! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 16, 13, 9, 36)},
#  {'reviewId': '5072db84-1b49-41e3-bba1-86405b8e1918',
#   'userName': 'ME Vin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmYoRPsBag1SKEqV1N2KxG_mRnKxaJtIKhERDk22A',
#   'content': 'Aplikasi ini sangat berguna, gapapa keluar uang sedikit. Yg penting, bisa konsultasi dengan dokter2 hebat. Dan itu sangat bermanfaat',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 14, 14, 10, 31),
#   'replyContent': 'Hai Me Vin! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2018, 12, 23, 13, 52, 30)},
#  {'reviewId': 'b0c91dc9-4407-48b3-91a3-a534cae6eb47',
#   'userName': 'Elis Hernawati',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClK89e_Sl1EVN4Dy51mJomdF_C3gVjj9LVLgIZq',
#   'content': "Alhamdulillah sejauh ini cukup membantu, dan untuk respon dokter pun cukup baik dan cepat. Semoga selalu kedepan'a terus bisa membantu tanpa ada hambatan 👍👍",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2023, 1, 8, 0, 20, 58),
#   'replyContent': 'Hai Elis Hernawati! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 8, 0, 27, 4)},
#  {'reviewId': 'bb075639-3ff0-445d-8897-7789ace962c0',
#   'userName': 'Dewi Marlisa',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp6rYK1PfvhuxFFpciHl6dHiXDrZzZqn67azmzmO=mo',
#   'content': 'Sangat efisien dan terbantukan banget,gak perlu antre lama2 utk konsultasi. recommended banget pokoknya, terima kasih halodoc',
#   'score': 5,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '15.700',
#   'at': datetime.datetime(2023, 1, 8, 16, 9, 48),
#   'replyContent': 'Hai Dewi Marlisa! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 8, 16, 36, 7)},
#  {'reviewId': '9d59fa25-c4c2-4e47-88b5-061d8fadff5d',
#   'userName': 'mirna anggraini',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCla8onmYA58uHvqE1Ij2uYw-WQEUHCpRKWRR7Otsw',
#   'content': 'Histori transaksi terakhir lama2 ga ada, ada obat pakai konsultasi dokter udh konsul dokter malah dibatalin dan dana konsul belum dikembalikan. CS virtual assistant di histori chat nya ilang. Awal pake apps ini bagus tapi kemudian ga konsisten bagusnya',
#   'score': 2,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2022, 12, 1, 7, 0, 49),
#   'replyContent': 'Hai mirna anggraini! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu agar dapat kami bantu lebih lanjut. Mohon kesediannya untuk menghubungi tim CS kami di menu bantuan aplikasi Halodoc agar dapat kami bantu lebih lanjut. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2022, 12, 1, 7, 14, 50)},
#  {'reviewId': 'ac4e41dc-c9e4-443e-b82d-b9748c98257c',
#   'userName': 'Rachmawati Nur Kalpitarini',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmDpcybycOx7ugzvgNR5GR-W3ROZSRPxmHEJtdBlQ',
#   'content': 'Saya kecewa dengan aplikasi ini, mau melakukan pembayaran tapi harus melengkapi data salah satunya upload KK dan pasport. Tapi gak jelas.',
#   'score': 3,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '15.600',
#   'at': datetime.datetime(2022, 12, 21, 20, 10, 47),
#   'replyContent': 'Hai Rachmawati Nur Kalpitarini! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor tlp +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 21, 22, 16, 50)},
#  {'reviewId': 'c116a985-3239-436a-935b-28aaeeacd8e7',
#   'userName': 'Tidar Property',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp66DVYD88loaFHqRPkyQb9JXw8ozp_qx49ZhCRf=mo',
#   'content': 'Aplikasi nipu...bayar 50 ribu ,chat 30 menit, kenyataan nya, sampai 30 menit waktu selesai tdk di balas, di balas nya setelah habis, jd kita tdk bz chat lagi...penipuan , hati2 pakai aplikasi ini..',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 30, 5, 55, 38),
#   'replyContent': 'Hai Tidar Property! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com',
#   'repliedAt': datetime.datetime(2022, 11, 30, 7, 20, 23)},
#  {'reviewId': '59295bb9-953f-45ce-89d0-2f166cda89b4',
#   'userName': 'Rendra Muhammad',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClLbFGlkVqgm0lZaPWe4FHQNaze951kfqVTjc0uMA',
#   'content': 'Pesanan sudah dianggap sudah beres tapi saya belum menerima pesanan, cutomer service lambat biaya layanan nya lambat lagi, merasa di tipu saya pakai layanan ini',
#   'score': 1,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 14, 10, 36),
#   'replyContent': 'Hai Rendra Muhammad! Mohon maaf atas ketidaknyamanannya. Saat ini kendala kamu sedang dalam pengecekan lebih lanjut oleh tim terkait kami, mohon menunggu konfirmasi berikutnya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, kamu juga bisa hubungi CS kami melalui nomor telepon +6221-5095-9900. Terima kasih dan sehat selalu.',
#   'repliedAt': datetime.datetime(2022, 12, 14, 14, 44, 47)},
#  {'reviewId': 'f721e21f-6d79-4703-9494-0ae532790351',
#   'userName': 'randi komara',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCnKMUbpGFUv4M1AqmHhihFTiZxe_pnK2VKt3I5VKw',
#   'content': 'Terimakasih apk bagus .. Saran aja di saat chat sama dokter kalau bisa dokternya jangan buru buru untuk keluar yah, karena di sayangkan kalau masih ada yang mau di tanyakan tapi sudah tidak bisa ..',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 18, 20, 36, 33),
#   'replyContent': 'Hai Randi Komara! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 18, 18, 22, 35)},
#  {'reviewId': 'd6b34a84-ed20-4433-a869-ba4125297203',
#   'userName': 'ZuLfani dinata',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmRxvwFd79eUK5ydiaYwKCK9fz7OGggkXuKR9Ofxg',
#   'content': 'Ini apLikasi bayar semua .... Baru mau chat aj udh di Lampirkan daftar harga ...dan beLum tentu pertanyaan kita terjawab sepenuhny.',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 9, 0, 59, 34),
#   'replyContent': 'Hai ZuLfani dinata! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu agar dapat kami bantu lebih lanjut. Mohon kesediannya untuk menghubungi tim CS kami di menu bantuan aplikasi Halodoc agar dapat kami bantu lebih lanjut. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2023, 1, 9, 1, 59, 45)},
#  {'reviewId': '80e7ca01-d1ae-4f25-873d-be21c25ddd75',
#   'userName': 'Sisca Lorenza',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmXMlRfMyPJy_1Wcx6jd5pmB3ixsGy3A9Yd30e2yg',
#   'content': 'Profil udah di isi semuanya tapi ga bisa di simpan, bisa jadi karna ga punya paspor. Apa harus punya paspor dulu baru bisa konsul? Padahal juga bisa bayar, kenapa ribet banget',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.401',
#   'at': datetime.datetime(2022, 12, 10, 8, 3, 3),
#   'replyContent': 'Hai Sisca Lorenza! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 10, 8, 40, 13)},
#  {'reviewId': 'ea7a61e6-9fc5-4729-8d67-f4a67bebb093',
#   'userName': 'sessy aryanthi',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClwtBQ1aFzqHov3Eeo2fSTNqO4B7AAntPJoyVM3Lf0',
#   'content': 'Sangat terbantu sekali, bs konsultasi dengan dokter yang berpengalaman. Dan saat di diberikan resep sesuai keluhan saya sebagai pasien, pengiriman obatnya juga terbaik👍 karena ga pake lama menunggu. Sukses selalu Halodoc👍🥰',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.401',
#   'at': datetime.datetime(2022, 12, 5, 18, 20, 26),
#   'replyContent': 'Hai sessy aryanthi! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 5, 18, 31, 37)},
#  {'reviewId': 'a2a95a4e-da95-4398-b114-06b046fd82f2',
#   'userName': 'Dini Chikal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCkrYln8bJaZG3KwpBedAy8SnVsBIHm6lIshFlPDb3g',
#   'content': 'Pengalaman pertama pake aplikasi halodoc. Alhamdulillah bnr² ngebantu bngt, trutama pas urgent mendadak sakit/kambuhan dan ga nyimpen obat. Bisa langsung pesen obat dan dikirim instan jd bs langsung konsumsi. Ditambah lagi, keren bngt, bs Konsul online sm dokter spesialis terbaik tanpa kuatir dngn biaya yg gede bngt 😁. Ada paketan Konsul dengan dokter harganya sangat miring, tanpa paketpun biaya dokternya sngt jauh lbh trjangkau ketimbang dtng ke RS. Obat manjur👍🏻. Praktis. Kereeeeeeeeeeeen🥳',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 12, 6, 14, 54),
#   'replyContent': 'Hai Dini Chikal! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 12, 6, 31, 28)},
#  {'reviewId': 'e4112164-c80c-42b2-8706-b9553a75e998',
#   'userName': 'Anggi Dia',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp4PTy2HCkjUg77_o1RfLdMcUkL3KQK3lNYWuYFt=mo',
#   'content': 'Nih klo obat ga sampe" tp di pemberitahuan apk uda diterima itu gimana? Tolonglahh antara apk, kurir jasa pengiriman dan apotiknya itu bisa kerja sama dgn baik. Jd mudah hubunginnya.. mau nanya paket obat yg blm sampe aja harusssss seribet ini dan nunggunya harus lama. Pdhl antibiotik lho dan hrus di mnum sesuai tgl rutinnya. Tolong kurir yg amanah dlm mngirim paketnya, dan apk ini tlong yg lngkap dong fiturnya mw lacak paket aja bingung hrus tnya siapa. Intinya kcewa. Dan ga akan pke apk ini.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 12, 13, 35, 50),
#   'replyContent': 'Hai Anggi Dia! Mohon maaf atas ketidaknyamanannya. Perihal kendala yang kamu alami saat ini sedang dalam pengecekan lebih lanjut oleh tim terkait kami dan mohon kesediaannya menunggu konfirmasi selanjutnya. Apabila ada kendala lain silakan hubungi tim CS kami di menu bantuan aplikasi Halodoc. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2023, 1, 12, 14, 7, 35)},
#  {'reviewId': '045ccc0a-0c0b-4b16-9ecd-557ae5b1193d',
#   'userName': 'Rabbit Hearted',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCnYr4RpLomxSdjVOv6AZqqyVwK86E1tlB7oh5E',
#   'content': 'Luar biasa pesanan sesuai yg di inginkan ,nyampe dg cepat .makasih yaaa',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 7, 13, 13, 29),
#   'replyContent': 'Hai Rabbit Hearted! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 7, 13, 43, 21)},
#  {'reviewId': '4df67132-dbe3-4ab9-a0e1-1fd0d30a2fdd',
#   'userName': 'Shinta Gustina',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClDsvotypFOpAjGKuSlc6bISeeVvin0wL2MPNft',
#   'content': 'Bagus banget halodoc ini mempermudah ketika kita tdk ada waktu untuk kerumah sakit dan kalau sedang urgent bisa langsung konsultasi ke dokter. Sukses terus halodoc..',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 13, 15, 16, 24),
#   'replyContent': 'Hai Shinta Gustina! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 13, 16, 4, 12)},
#  {'reviewId': 'cea87018-0da1-4bb3-ad35-a0a810b57f23',
#   'userName': 'Hasbullah Perkasian',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCnJ22JMfLs5mu8DLxwyjQHQMgrA_RhZ2X9Orm0SeA',
#   'content': 'Dokternya responsif, puas sesuai dengan yang saya harapkan, tidak perlu keluar rumah, terima kasih halodoc, sukses terus,',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 10, 19, 27, 8),
#   'replyContent': 'Hai Hasbullah Perkasian! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 10, 19, 28, 46)},
#  {'reviewId': '966ca323-a2bd-4858-9e02-5848c075142c',
#   'userName': 'Gita Ayurahma',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCn3HGn6zs7U2VqpGGpEggStXvzxulRAOKj6geRr',
#   'content': 'Sangat membantu dalam konsultasi dengan dokternya. Belum sempat bilang makasih kedokterannya waktu nya cepat kalii sudah 30 menit aja😊🙏',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 6, 23, 43, 44),
#   'replyContent': 'Hai Gita Ayurahma! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 6, 23, 52, 30)},
#  {'reviewId': '4693e7f5-7031-4b95-8074-076b827b2b11',
#   'userName': 'welly nadia',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCm0B7SoGiG8DsuwrdV2T3mDbe0vd1REhtTvjCa0qw',
#   'content': 'Sangat membantu dan memudahkan anak kos yang lagi sakit ga bisa pergi ke dokter langsung sndiri, dengan app ini kita bisa Konsul dan langsung diresepkan obat, terbaiksss',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '15.600',
#   'at': datetime.datetime(2022, 12, 21, 20, 10, 38),
#   'replyContent': 'Hai welly nadia! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 21, 22, 16, 2)},
#  {'reviewId': '5fd59a57-d4c9-4a1c-8207-38e4904726d4',
#   'userName': 'Diana Wonder',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5QlI4e7-KyU2C_pQ30cvtoiH-L0ckYx4wFhIwz=mo',
#   'content': 'Aplikasi nya error.pembayaran berhasil tp gagal di aplikasi dibatalkan uang susah banget baliknya prosesnya email dan kirim bukti screenshoot segala macam jg blm balik..parah halodoc skrg',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 19, 15, 13, 32),
#   'replyContent': 'Hai Diana Wonder! Mohon maaf atas ketidaknyamanannya saat ini kendala tersebut dalam pengecekan oleh team terkait kami. Mohon kesediaannya menunggu konfirmasi selanjutnya dari CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 11, 19, 15, 38, 27)},
#  {'reviewId': '45eb1ef5-83f3-4427-97c3-c9d0c578b5c3',
#   'userName': 'Qisti Fadilatussaniatun',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCm8GsBs7_kWDbcweEuOJbgFHLApFQhQZkomsyTxH9A',
#   'content': 'Kok harus log in terus ya ? Mau log in lewat no telp ko gabisa di klik sih mau ketik angkanya ? Mohon segera dijawab',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '16.001',
#   'at': datetime.datetime(2023, 1, 16, 17, 43, 58),
#   'replyContent': 'Hai Qisti Fadilatussaniatun! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2023, 1, 16, 17, 51, 50)},
#  {'reviewId': '462585b2-5ffd-4eba-b751-ff37c0dfc613',
#   'userName': 'Mohammad Ewa Saputra',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClqzsDJ6q17G6FfHbi1yHEH1L1R1M16ETEhu3y31A',
#   'content': 'pakai cuma digojek buat order obat, dan ini saya baru mau coba appnya buat konsul, tapi sistemnya ribet, bayar konsul Dokter yang online, langsung dihubungi dengan dokter harus nunggu 2 menit, tapi ga terhubung, dan gagal konsul muncul notif sibuk blabla, niat mau cari dokter yang lain aja, ternyata saldo terpotong nunggu di refund.jadi repot kalo topup saldo ngepas. kalo emng gbisa atau sedang konsul dngn pasien lain lebih baik diberi tanda, atau di offline kan saja. diperbaiki lagi sistemnya !',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '16.001',
#   'at': datetime.datetime(2023, 1, 15, 21, 15, 37),
#   'replyContent': 'Hai Mohammad Ewa Saputra! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2023, 1, 15, 22, 32, 34)},
#  {'reviewId': '7054163a-ba69-484b-a3ed-e522db8cc51e',
#   'userName': 'Ratna Indrawasih',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp6PA1EvEswrvLt3xtBqis2nn5_72kPUjXhNGSSf=mo',
#   'content': 'Alhmdulillah cukup membantu. Konsultasi cukup memberi info masalah kesehatan yang saya alami dan mendapat solusi dan saran baik. Tks dokter Diani, Tks halodoc',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '16.001',
#   'at': datetime.datetime(2023, 1, 17, 9, 3, 6),
#   'replyContent': 'Hai Ratna Indrawasih! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu.',
#   'repliedAt': datetime.datetime(2023, 1, 17, 9, 10, 42)},
#  {'reviewId': 'fe3a86de-ff80-416d-b8e9-77215e622d99',
#   'userName': 'Rizal Player Indonesia',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmFYhJSXlFCtVBSW8JfVsWy7bpSXYdsGEJ1rwo15w',
#   'content': 'Kukira gratis wkwk ,kaum miskin mah berdoa aja klo mau sembuh penyakitnya sambil browsing di youtube atau google cari apa aja larangan dan cara pengobatan alternatifnya ,klo emang sakit udah parah mau ga mau ya emang harus ke dokter',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 19, 2, 58, 47),
#   'replyContent': 'Hai Rizal Player Indonesia! Mohon maaf atas ketidaknyamanan yang terjadi. Saat ini sudah diberlakukan penyesuaian biaya atas layanan pada aplikasi dan kami harap untuk pelayanan dapat lebih maksimal. Informasi lebih lanjut silakan hubungi tim CS kami di menu bantuan aplikasi Halodoc. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2022, 12, 19, 3, 8, 1)},
#  {'reviewId': 'e48d7002-f5db-4a5c-8e82-fb36e6f8e48c',
#   'userName': 'VALERIA PRAMITA',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5hCGgo91uP88LOHhiybX--T3iHTgOKcfsLbfkpEg=mo',
#   'content': 'Ribet, cuman ganti no hp gk bisa login alhasil bikin new profile dg new number tapi data sama dg akun lama alhasil gak bisa login sudah d call center dan email tp instruksi yg diberikan tetep gak membuahkan hasil, ribeut banged',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.400',
#   'at': datetime.datetime(2022, 12, 3, 17, 11, 23),
#   'replyContent': 'Hai VALERIA PRAMITA! Mohon maaf atas ketidaknyamanannya. Saat ini kendala kamu sedang dalam pengecekan oleh tim terkait kami. Mohon menunggu konfirmasi berikutnya. Terima kasih dan salam sehat selalu',
#   'repliedAt': datetime.datetime(2022, 12, 3, 18, 21, 44)},
#  {'reviewId': 'd9621ad5-2a24-4542-9d78-5b53b964571f',
#   'userName': 'Akilah Kt',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp4M6KGG08RyCJA7ZbrTXE3QzKb3v5M7NY_EEkFT=mo',
#   'content': 'Pengantaran obat sangat lamaaa dikemas padahal sudah payment. Tolong diperbaiki pengiriman obatnya agar lebih cepat. Padahal sudah bayar ongkir juga',
#   'score': 1,
#   'thumbsUpCount': 12,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2022, 12, 4, 1, 27, 32),
#   'replyContent': 'Hai Akilah Kt! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 4, 1, 41, 20)},
#  {'reviewId': '739daf81-77c8-4bd4-bc63-431aa07199b3',
#   'userName': 'Anieta Jkt',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp726nC5SqVYbSLS1hRa__HZ28EOgYVIN8zBovYs=mo',
#   'content': 'Pengalaman sakit batuk flu bagus dan obatnya paten, pengalaman penyakit kulit di kedua jempol gak bagus obatnya gak mujarab tapi mahal.',
#   'score': 4,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 18, 14, 22, 22),
#   'replyContent': 'Hai Anieta Jkt! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 11, 18, 14, 38, 20)},
#  {'reviewId': 'e66708c3-5eae-4048-966d-a8e986f480a5',
#   'userName': 'sabilla rusdi',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp4fwBZIMXtBxdOIZeHDKR97n4opTKrnISLYUCLS=mo',
#   'content': 'Dapet resep dr dokter di aplikasi, saya pergi ke apotek halomedika yg di recomend dr aplikasi, kebetulan jarak dr rumah saya cuma 10meter, pas sampe sana resep saya di tolak, katanya pembelian harus menggunakan aplikasi,. Harus bayar ongkir lagi gojek nya 18rb.. yaelah tibang 10M sejauh apa sih emang harus pake wajib abang gojek yg ambilin,.. pas saya pesen melalui abang gojek, saya ceritain abang nya ketawa2 aja.. jd lucu dah 😅😅',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '15.700',
#   'at': datetime.datetime(2022, 12, 29, 20, 48, 44),
#   'replyContent': 'Hai Sabilla Rusdi! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 29, 21, 3, 25)},
#  {'reviewId': 'fff4ab23-f1e9-4e57-8ccc-f9120b6d4c23',
#   'userName': 'Annisa Riski Rahayu',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCnlHZe5k1YsZF9vQhplwojpDY9qu73_BP8MxumqYg',
#   'content': 'Aplikasi ini sangat membantu sekali.. chat dokter yg ramah serta jelas penyampaiannya.. thank you halodoc😊',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2023, 1, 13, 15, 32, 7),
#   'replyContent': 'Hai Annisa Riski Rahayu! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 13, 16, 4, 37)},
#  {'reviewId': 'd63471ce-d268-4394-9a6c-7e18b6520f44',
#   'userName': 'M. Rio Fardani Al Hasan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClUWi-wbS-s9wQD448yBwo_Ocdq6HS-elWmI6kB',
#   'content': 'Bagus sekali sesi skrinningnya sangat baik. Dan lumayan murah lah meski cuma via online. Fast respon juga',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 13, 22, 42, 5),
#   'replyContent': 'Hai M. Rio Fardani Al Hasan! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 13, 22, 45, 32)},
#  {'reviewId': 'b91ff45a-33d2-4c7a-9aa7-b9bd3b8aa09e',
#   'userName': 'aprilia kartini',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp742K9KmFSIWwnLSq90L_ZklZoWayJ4uvr4HVVI=mo',
#   'content': 'Sangat membantu apalagi sudah bekerjasama dengan asuransi BNI LIFE, jadi mudah. Pelayanan cepat dan oke',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 17, 18, 22, 26),
#   'replyContent': 'Hai Aprilia Kartini! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 17, 18, 25, 34)},
#  {'reviewId': 'b77a7c37-ca10-4c98-bfb1-b1b1d4553f93',
#   'userName': 'Shinta Fury',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5eHZ-7bvrd8xJ6rg3vsav57SqdWtNNMy37BCFT=mo',
#   'content': 'Pelayanan baik, dan juga cepat, Jika ada barang yg kurang, langsung di kirim di hari yg sama , Produk original, jadi ngga khawatir kalo mau beli obat, Aplikasi juga mudah di gunakan.',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 11, 18, 25, 42),
#   'replyContent': 'Hai Shinta Fury! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 11, 11, 20, 20, 24)},
#  {'reviewId': '5f58cfe1-006d-4185-8adf-f8a5852506c5',
#   'userName': 'Rudi Dwi Atmojo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClxF2M4BF2pmQsSb1K_Zt4k_JD-EPTdgex8tA9r',
#   'content': 'Heran, udah d ganti sesuai profil tetap selalu kena error obat tidak sesuai dengan profile. Meresahkan',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2022, 12, 5, 0, 18, 21),
#   'replyContent': 'Hai Rudi Dwi Atmojo! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 5, 0, 25, 18)},
#  {'reviewId': '6166b682-6bb6-4a19-9329-5280b463fd46',
#   'userName': 'Edy Kurniawan Siregar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmQ4WaBH3YAkbNjMn9xWQdysGouTatXyfgCW4YZjA',
#   'content': 'Ok mantap, respon cs live chat nya oke, namun respon cs agent email sangat lambat. Mohon di perbaiki karena ini adalah aplikasi pelayanan kesehatan. Seharusnya harus lebih fast respon semuanya',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2022, 12, 7, 9, 43, 13),
#   'replyContent': 'Hai Edy Kurniawan Siregar! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 7, 9, 45, 16)},
#  {'reviewId': '6a366a3d-5b70-46de-a433-9ac77f07a79d',
#   'userName': 'Anggita Martina Pratama',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClFnEIx6NmWwUQXYk2fa-M6LlNM2htrsnAIHjLx7A',
#   'content': 'Berapa puluh kali pesan obat, bahkan sudah konsultasi dan diresepkan Dr. Tetapi pemesanan obat saya selalu terbatalkan otomatis oleh sistem, dan itu berulang seperti yang ngebanned aku saya seolah2 saya tidak bisa pesan obat apapun. Dalam hitungan detik selalu saja terbatalkan. Kendalanya dimana ini ?',
#   'score': 1,
#   'thumbsUpCount': 54,
#   'reviewCreatedVersion': '15.000',
#   'at': datetime.datetime(2022, 10, 28, 6, 46, 33),
#   'replyContent': 'Hai Anggita Martina Pratama! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 10, 28, 6, 54, 47)},
#  {'reviewId': 'c9563610-49ab-4e0d-ab47-f82bb62e35f9',
#   'userName': 'Insan Tersesat',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCn6z5giy3t_CGiJOSkW4EfF8BFmMhi4oGyrsHXHJYM',
#   'content': 'Tolong do, jangan ubah rating dari saya. Masa iya lagi konsultasi tiba-tiba berhenti? Dicoba lagi gak tetep gak bisa, uninstall menjadi jalan terakhir, kalau tetap gak bisa dibuka. Semoga Tuhan memberi kebaikan 🙃',
#   'score': 5,
#   'thumbsUpCount': 58,
#   'reviewCreatedVersion': '15.000',
#   'at': datetime.datetime(2022, 10, 30, 16, 5, 33),
#   'replyContent': 'Hai Insan Tersesat! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 10, 30, 16, 30, 33)},
#  {'reviewId': '003d89c2-4b46-48e1-a403-b797a9673bfd',
#   'userName': 'Rian Rahmat',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCkBAxw_j9l_dW7krnSkonh9hOkqrIAYfvqsvLIKMg',
#   'content': 'Aplikasi nipu, sudah download dan daftar tapi gak dapat hadiah dari game lain, gw download karena task dari game tapi gak dapat, penipuan',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '15.600',
#   'at': datetime.datetime(2022, 12, 21, 18, 1, 44),
#   'replyContent': 'Hai Rian Rahmat! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor tlp +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2022, 12, 21, 18, 33, 32)},
#  {'reviewId': 'c5292728-18ed-4a01-b2b3-3def1b94d31c',
#   'userName': 'Khalid Zulkarnaen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp7vmxwG6hLSMP28O7E-SJ_c7xVK5Yh1f5UkScb7Tg=mo',
#   'content': 'Apps yang sangat banyak manfaat, membantu n memudahkan.. cepat praktis lengkapsss...',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2022, 12, 6, 2, 8, 43),
#   'replyContent': 'Hai Khalid Zulkarnaen! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 6, 5, 8, 25)},
#  {'reviewId': '5f9dc820-e8c1-4d21-89c3-f391df5c52e8',
#   'userName': 'Nurdina Bestari',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCn7ho_fxowIbYs-jAI3lQYyX_hyJSBbsyKGVrhIqA',
#   'content': 'Salah satu kelemahan halodoc adalah tidak bisa cek apotek saat mau nebus resep online. Apotek dipilih langsung oleh Halodoc tanpa ada konfirmasi, dan uniknya misal dpt 3 obat dari Dokter, itu belinya bisa dari apotek yg berbeda2, sehingga ongkir double2 (sungguh tidak efisien). Tolong lah diperbaiki',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 14, 20, 33, 49),
#   'replyContent': 'Hai Nurdina Bestari! Mohon maaf atas ketidaknyamanannya. Terima kasih atas feedback yang telah diberikan. Perihal tersebut akan menjadi evaluasi bagi Halodoc untuk meningkatkan kualitas pelayanan Halodoc. Apabila ada yang dapat kami bantu, silakan hubungi CS kami melalui nomor telepon +6221-5095-9900 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2023, 1, 14, 21, 3, 14)},
#  {'reviewId': 'a12fb2e5-8db4-4c50-96e8-49484aa15355',
#   'userName': 'Rizqi Yurinka',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmK7IenOV2IBjfnPhclcTkTU34wko5dUHYvmFH0iA',
#   'content': 'Lengkap obatnya, dqn juga banyak apotiknya jadi meskipun apotiknya jauh tapi obatnya sudah pasti tersedia. Respon dokternya bagusbagus, proses pesananannya juga cepat. Terima kasih👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.100',
#   'at': datetime.datetime(2022, 11, 13, 12, 10, 10),
#   'replyContent': 'Hai Rizqi Yurinka! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 11, 13, 12, 14, 27)},
#  {'reviewId': 'a1503bdb-67c9-4867-b6ab-62a72afb3042',
#   'userName': 'Sutono Nalin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp49dSd3lXeRBcZiZSJPf5IivdXM5vq-c3ujKkOL=mo',
#   'content': 'Cepat tangap , aplikasi yg sangat membantu .',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.801',
#   'at': datetime.datetime(2023, 1, 10, 19, 35, 26),
#   'replyContent': 'Hai Sutono Nalin! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 10, 19, 59, 36)},
#  {'reviewId': '7fcbf8c8-9bee-4302-90d5-aa28fca6fb9c',
#   'userName': 'Edy Sutedy',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp7HNDRCIVxBcEjXQ8q8hAxfcVWjl-5gySffP7LR=mo',
#   'content': 'Sangat Mudah Belanja di Halodoc disertai dengan tenaga ahli yang benar-benar profesional cuma hanya di Halodoc dan pengiriman sangat cepat',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.600',
#   'at': datetime.datetime(2022, 12, 23, 23, 12, 6),
#   'replyContent': 'Hai Edy Sutedy Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 23, 23, 17, 43)},
#  {'reviewId': '172df070-a43c-4ab2-a4f7-a565318a8029',
#   'userName': 'ferary sahita',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5RL7KP6B9VvEbjx8w43zJNCjKfFJqAgwIOExvc=mo',
#   'content': 'Sangat membantu untuk keadaan darurat dan tdk perlu lama2 mengantri..',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.300',
#   'at': datetime.datetime(2022, 12, 29, 9, 27, 39),
#   'replyContent': 'Hai ferary sahita! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 29, 10, 29, 25)},
#  {'reviewId': '7817985e-18a0-445e-8299-28f9fe40d26e',
#   'userName': 'Nur Indira Wardhani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp70Mhul4SJ6BxS08Iaa9Ot9fKtVgbDtLjSwET5O=mo',
#   'content': 'Sakit tidak perlu keluar rumah lagi, cukup konsultasi online, dapat resep juga Sangat membantu saat tidak ad yg mengantar/ konsultasi di jam berapapun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.502',
#   'at': datetime.datetime(2022, 12, 29, 21, 14, 17),
#   'replyContent': 'Hai Nur Indira Wardhani! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2022, 12, 29, 21, 23, 24)},
#  {'reviewId': '57643fe7-12ec-4bc9-875b-07ed9b394003',
#   'userName': 'Lia Dahlia',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCkt-lvSioxq1nQPTJO4hv25KmId6p6-OdhaGHfx',
#   'content': 'Sangat membantu, bisa melakukan pemesanan obat jg.. aman juga lengkap dengan resep obatnya',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '15.700',
#   'at': datetime.datetime(2023, 1, 18, 12, 49, 38),
#   'replyContent': 'Hai Lia Dahlia! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2023, 1, 18, 12, 55, 20)},
# ...
#   'score': 1,
#   'thumbsUpCount': 36,
#   'reviewCreatedVersion': '5.901',
#   'at': datetime.datetime(2019, 11, 14, 14, 6, 5),
#   'replyContent': 'Hai Tianda! Mohon maaf atas ketidaknyamanannya. Mengenai kendala yang kamu alami saat ini sedang dalam pengecekan dan mohon menunggu info lebih lanjutnya, apabila ada kendala lainnya silahkan hubungi CS kami melalui “Chat with us” di menu bantuan aplikasi Halodoc.',
#   'repliedAt': datetime.datetime(2019, 11, 14, 15, 20, 41)},
#  {'reviewId': '48fb03d7-0340-4dd0-999d-0c4a540f4c44',
#   'userName': 'Fitri Suryani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp5n5wcNGUkdfgZxPhW7fjTZJY-lDy-niAhJC-CN=mo',
#   'content': 'cukup senang atas arahan"nya dan sangat membantu sekali jg meringankan mental sy yang lagi droop sakit tentunya di massa sprt ini yg sangat menguwatirkan "terimakasih dok... cukup puas walau percakapan sedikit terputus " mudahan "bs terhubung kembali .',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '7.140',
#   'at': datetime.datetime(2020, 5, 7, 10, 20, 36),
#   'replyContent': 'Hai Fitri Suryani! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2020, 5, 7, 10, 27, 58)},
#  {'reviewId': '3f22d5f1-b31a-4496-a410-28a0bdeab6c4',
#   'userName': 'duabelas noldua',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp4Phvssu4fMzYMBbRhkC4rmAljPqcz47A58KjMp=mo',
#   'content': 'Aplikasi nya aneh dan merugikan..kita order janji ke klinik sdh bayar tp pesanan tidak dikonfirmasi sampai lewat waktu yg di order trus orderan batal otomatis gopay dikembalikan tapi kenapa kita di charge, kan yg batalin dari pihak aplikasi...apa mungkin aplikasi ini ada kerja sama dengan instansi/dokter agar tdk dikonfirmasi? Biar dpt untung dari charge pelanggan. Bisa dilaporin gak sih ini',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 1, 5, 16, 37, 44),
#   'replyContent': 'Hai duabelas noldua! Mohon maaf atas ketidaknyamanan yang terjadi. Kami memerlukan informasi lebih lanjut perihal kendala kamu, silahkan hubungi tim CS kami melalui “chat with us” di menu bantuan aplikasi Halodoc. Terima kasih sudah menggunakan Halodoc.',
#   'repliedAt': datetime.datetime(2021, 1, 5, 16, 47, 8)},
#  {'reviewId': 'f484ae32-105f-426a-bc3c-28e3749f230c',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Aplikasi nya bagus banget. Fast respon dan ada riwayat pendidikan dari masing2 dokter dan pekerjaan nya dimana saja tertera dengan jelas. Jadi engga ragu ketika dikasih saran👌😍😍😍😍keren bgttt',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.901',
#   'at': datetime.datetime(2019, 11, 11, 18, 14, 24),
#   'replyContent': 'Hai Ria Sarju! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 11, 11, 18, 37, 22)},
#  {'reviewId': '94196abc-17fa-4b20-b763-d9d181ebd302',
#   'userName': 'Bambang Dwi Prasetyo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp6ZXfBVRBqsFdBG7f5E0MNoTpUeNIRUr2woFQLR=mo',
#   'content': 'applikasi nya susah untuk penilaian, tidak bisa edit alamat, cuma bisa chat driver via sms,, sangat merepotkan dan tidak praktis',
#   'score': 2,
#   'thumbsUpCount': 6,
#   'reviewCreatedVersion': '11.200',
#   'at': datetime.datetime(2021, 12, 19, 7, 49, 2),
#   'replyContent': 'Hai Bambang Dwi Prasetyo! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silakan hubungi CS kami melalui nomor telepon +6285574677403 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2021, 12, 19, 8, 7, 50)},
#  {'reviewId': 'a96378d2-d4e3-4e63-ac10-bd303482e890',
#   'userName': 'Anjelia Siahaan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCnlufpuvpYX4f9j9yMws1OuRvztCg-6Fup429kOiA',
#   'content': 'Pelayanan buruk, saya buat janji PCR sampe skrg tidak ada konfirmasi. Dan telpon customer care tidak ada yg respon begitu jg d email/chat with us!! Gimana saya mau PCR ditempat lain kalo duit saya belum dibalikin!! Tolong diperbaikin lagii, jangan slow respon bgt semua org pengguna Halodoc pasti butuh cepat bukan untuk dipersulit!!!',
#   'score': 1,
#   'thumbsUpCount': 24,
#   'reviewCreatedVersion': '8.601',
#   'at': datetime.datetime(2021, 1, 4, 6, 24, 4),
#   'replyContent': 'Hai Anjelia Siahaan! Mohon maaf atas ketidaknyamanan yang terjadi. Sesuai konfirmasi melalui layanan bantuan yang disampaikan kendala kamu saat ini sedang dalam proses investigasi. Mohon menunggu. Apabila ada kendala lain silahkan hubungi customer service kami melalui "chat with us" di aplikasi Halodoc.',
#   'repliedAt': datetime.datetime(2021, 1, 4, 7, 16, 11)},
#  {'reviewId': 'c6c116b5-eb8d-4d77-8b06-ecd3cac53901',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'ya dokter2 nya sangat Baik dan ramah, tapi kurangnya yaitu ketika jawab pesan mungkin agak lama, ya tapi saya maklumin lah, karena semua manusia itu pasti mempunyai urusan2 ny masing masing',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.100',
#   'at': datetime.datetime(2019, 7, 7, 23, 0),
#   'replyContent': 'Hai Maulana Assalamatul Ulya! Terima kasih sudah menggunakan Halodoc . Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 7, 7, 23, 11, 59)},
#  {'reviewId': 'd632554d-0d19-4f4c-82a1-93189b5e40d1',
#   'userName': 'FIRMAN SETIAWAN',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCmNd4VzViJwpVfwTVytaYh78_PHDViAOACL-9lLvA',
#   'content': 'Konsultasi perdana dengan dokter umum. Sangat fast respond. Segala tips dan obatnya dikasih tau. Makasih yah dok. InsyaAllah. Rejeki dokter lancar. Sehat selalu. Untuk halodoc, sukses appnya dan tingkatkan terus sistemnya.',
#   'score': 5,
#   'thumbsUpCount': 14,
#   'reviewCreatedVersion': '8.601',
#   'at': datetime.datetime(2020, 12, 25, 13, 29, 39),
#   'replyContent': 'Hai FIRMAN SETIAWAN! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2020, 12, 26, 21, 42, 20)},
#  {'reviewId': '5c98d998-d3ed-4522-a752-0225f86777fd',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'first experience yang memuaskan, konsultasi by chat bisa attach media.. dapet resep bisa langsung dibeli dan diantarkan.. app yg menjawab kebutuhan sekali.. semoga tetap sehat semuanyaaaaa :)',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.310',
#   'at': datetime.datetime(2019, 8, 15, 22, 4, 17),
#   'replyContent': 'Hai Patricia Alvani Gultom! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 8, 15, 22, 36, 28)},
#  {'reviewId': '40817ff5-6653-40f5-8c29-cefec6be7545',
#   'userName': 'Valencia Victoria',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCn4D3BpHEbUydEseG8_uo9AiCjy2lwEGAckqEqRHw',
#   'content': 'kecewa banget jujur, setiap mau beli obat disini aplikasinya selalu nggak berfungsi. ngebug terus gabisa di pencet apa apa padahal hp saya baik baik aja dan bisa buka aplikasi yang lain. tolong diperbaiki ya,',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '8.800',
#   'at': datetime.datetime(2021, 1, 26, 17, 33, 14),
#   'replyContent': 'Hai Valencia Victoria! Mohon maaf atas ketidaknyamanannya. Untuk dapat kami bantu lebih lanjut terkait kendala yang kamu alami, silahkan hubungi CS kami melalui nomer telepon +6285574677403 atau email help@halodoc.com.',
#   'repliedAt': datetime.datetime(2021, 1, 26, 17, 37, 24)},
#  {'reviewId': '40d57f96-6af8-417e-88f0-057a498961e0',
#   'userName': 'Abid Dzakwan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCm74tznmqv129HQy6f1eP_IONc8TiPiCKHZgf02MQ',
#   'content': 'Cepat sekali responnya..dokternya pun cepat membalas setiap keluhan...amat sangat membantu sekali di masa seperti ini... Hanya saja mungkin kalau telpon dan video amat terbatas karna jaringan... Terimakasih untuk para dokter di seluruh indonesia yg selalu siap melayani setiap para konsumen🙏🙏🙏🙏🙏👍👍👍👍👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 12, 24, 8, 2, 25),
#   'replyContent': 'Hai Abid Dzakwan! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2020, 12, 25, 19, 15, 33)},
#  {'reviewId': 'afd07fae-9675-4723-989b-474a88d662c5',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'App yg sangat bagus dan Sangat membantu , dokter2 ramah , dan asalkan kita konsul nya rinci dan jelas, pasti saran dan diagnosa dari dokternya tepat . Semoga app selalu berkembang dan kedepan nya bisa menjangkau daerah2 selain ibukota yaa 🤗 sukses terus buat halodoc 👌',
#   'score': 5,
#   'thumbsUpCount': 31,
#   'reviewCreatedVersion': '5.900',
#   'at': datetime.datetime(2019, 10, 30, 10, 47, 2),
#   'replyContent': 'Hai Nurul Fajryah putri! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu',
#   'repliedAt': datetime.datetime(2019, 10, 30, 11, 24, 26)},
#  {'reviewId': 'fd4619a0-dd9f-4db8-a884-f499b90b42bf',
#   'userName': 'dwi sulistiani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClxRvGMUTYM3gizyBOt6oCU42fpkh1eAqvK5BnO6dU',
#   'content': 'saya coba dulu ya resep dari dokter untuk saya jd saya kasih rating 4 terlebih dahulu, overall konsultasi nya karna terbilang singkat jd mengutarakan nya kudu cepet ngetiknya. Thanks dokter sudah membantu saya 🙋',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '10.801',
#   'at': datetime.datetime(2021, 11, 4, 23, 8, 35),
#   'replyContent': 'Hai dwi sulistiani! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2021, 11, 4, 23, 14, 40)},
#  {'reviewId': '0f3b16c7-2945-4112-a8c5-11876e41a42f',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'invoasinya sih bagus bisa konsul dan beli obat di aplikasi, tapi sangat di sayangkan ada beberapa dokter yang menjawab dengan ogah2an walaupun kami dari sisi pasien mendapatkan free konsultasi tp dari sisi dokter kan tetap mendapatkan fee dari konsultasi yang di lakukan, harusnya bisa menjawab semua pertanyaan pasien dengan sabar dan informatif. terima kasih',
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '5.500',
#   'at': datetime.datetime(2019, 9, 12, 16, 22, 52),
#   'replyContent': 'Hai Tri Prihansen! Mohon maaf atas ketidaknyamanannya. Untuk meningkatkan kualitas pelayanan konsultasi mohon untuk menginformasikan nama dokter yang dimaksud kepada customer service kami melalui “chat with us” di aplikasi Halodoc.',
#   'repliedAt': datetime.datetime(2019, 9, 12, 17, 10, 52)},
#  {'reviewId': '4c9a8cbb-d763-4d09-b837-bf87e1a8291c',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'aplikasinya bagus dan sangat membantu. tapi utk menebus obat yg diresepkan dokter, sepertinya masih tidak bisa dinikmati oleh luar daerah jabodetabek. alangkah baiknya jika area layanan nya juga tersebar di seluruh wilayah indonesia. trimakasih halodoc, sangat2 membantu sekali',
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '4.601',
#   'at': datetime.datetime(2019, 4, 14, 22, 2, 34),
#   'replyContent': 'Hai Silvia Kardena! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 4, 14, 22, 35, 12)},
#  {'reviewId': '262d5fc4-a9cc-434a-9644-337843d2f813',
#   'userName': 'Oka Fridayah',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WCk1ARfjk2NF2visg18LgQYvoLTf1kVYBQkCl6wFzQ',
#   'content': 'Sangat bermanfaat aplikasi ini ..terutama disaat pandemi ...karena saya menghindari bertemu dgn orang lain....saya selalu di rumah saja.Terpaksa keluar rumah jika harus berbelanja dan ke apotek saja.',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '9.900',
#   'at': datetime.datetime(2021, 7, 27, 14, 25, 12),
#   'replyContent': 'Hai Oka Fridayah! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu.',
#   'repliedAt': datetime.datetime(2021, 7, 27, 14, 27, 4)},
#  {'reviewId': '33ddc10e-62a4-4334-a085-d80475955911',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'masalah dokternya ramah atau tidak itu tergantung personal & apakah anda menggunakan fitur gratis atau bayar,pelayanan yg diberikan cukup baik,ini juga menunjukkan kedokteran mengikuti arus zaman,dimana semua hal dimudahkan,thanks halodoc!🙏🏼',
#   'score': 4,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '5.310',
#   'at': datetime.datetime(2019, 8, 16, 10, 19, 7),
#   'replyContent': 'Hai Muhammad Solihin! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 8, 16, 10, 38, 45)},
#  {'reviewId': '32a54fbb-3abf-409f-b96a-3e561c4b6ba3',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'pertama kali gunain merasa sangat terbantu. tapi yg saya kurang suka obatnya harus di beli di tempat yg ditentukan, pengalaman saya karna sakitnya malem jadi mas mas gojeknya bilang tempatnya sudah tutup dan tidak bisa ke apotik lain jadi banyak yg cancel, akhirnya resep saya catat trus mesen di go-shop. dan berhasil.',
#   'score': 5,
#   'thumbsUpCount': 35,
#   'reviewCreatedVersion': '5.310',
#   'at': datetime.datetime(2019, 8, 19, 12, 40, 30),
#   'replyContent': 'Hai PBworld 12! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 8, 19, 11, 22, 10)},
#  {'reviewId': 'd71deb7e-e688-4203-9636-6bb6348e77e0',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Sangat suka dengan aplikasi ini, karena saya tinggal didesa jauh mau konsultasi kedokter, dengan harga konsultasi yang lumayan. Dengan adanya aplikasi ini serasa dekat mau konsultasi pun, tanpa perlu keluar rumah. Hanya resep obat saja yang harus dibeli. Puassss banget.... Sekarang gak bingung lagi terimakasih app Holodoc. Sangat membantu.',
#   'score': 5,
#   'thumbsUpCount': 35,
#   'reviewCreatedVersion': '6.001',
#   'at': datetime.datetime(2019, 11, 24, 21, 9, 50),
#   'replyContent': 'Hai Chichik Hory Suprapti! Terima kasih sudah menggunakan Halodoc. Jangan lupa untuk jaga kesehatanmu dengan Halodoc. Semoga kamu sehat selalu!',
#   'repliedAt': datetime.datetime(2019, 11, 24, 22, 16, 46)},
#  ...]

# %%
import pandas as pd
df = pd.DataFrame(reviews)
df
# Out:
#                                   reviewId              userName  \
# 0     4f9da834-8ef2-431f-9f0f-81c3457a9125         wafi izzudien
# 1     f310241e-f30b-4a27-8011-94f0ccdb4615           Suga Dillah
# 2     3c3c832d-a2e5-4b5d-b17c-621b385405b3    002 Syifaul Amrodi
# 3     44ade954-5703-45e5-9472-6675b6fb113e  Ariaya Nur Anggarani
# 4     fda13ade-581f-41af-a505-2222138ac103             Kuskus 01
# ...                                    ...                   ...
# 4995  97b97128-5c40-449c-abe0-5787175afeb0       Pengguna Google
# 4996  99362173-b500-45d1-a89c-91bad69dbdad      Ika Sanrif Migas
# 4997  9b71d94c-ac97-46cb-a3ce-bbf5a53f5eb4       Pengguna Google
# 4998  b1a82cfa-5480-4d34-bcdf-521ff72312a2       Pengguna Google
# 4999  c225f32c-5536-4732-920a-6e8ca17b0aec       Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/AD5-W...
# 1     https://play-lh.googleusercontent.com/a-/AD5-W...
# 2     https://play-lh.googleusercontent.com/a-/AD5-W...
# 3     https://play-lh.googleusercontent.com/a/AEdFTp...
# 4     https://play-lh.googleusercontent.com/a-/AD5-W...
# ...                                                 ...
# 4995  https://play-lh.googleusercontent.com/EGemoI2N...
# 4996  https://play-lh.googleusercontent.com/a-/AD5-W...
# 4997  https://play-lh.googleusercontent.com/EGemoI2N...
# 4998  https://play-lh.googleusercontent.com/EGemoI2N...
# 4999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0     Di antar banyaknya rating bintang 1, belum ten...      5             14
# 1     Sengaja daftar vaksin di halodok biar cepet. D...      1             12
# 2     Saya kesel banget sama aplikasi ini. Saya udah...      1             20
# 3     Kalau dokternya tidak standby tolong jangan di...      1             65
# 4     Hallo HALODOC. Kenapa pesanan saya tidak sampa...      3             32
# ...                                                 ...    ...            ...
# 4995  sangat suka sekali dgn aplikasi ini,, dokterny...      5              0
# 4996  Penjelasan yg sangat bagus, sangat membantu sa...      5              0
# 4997  Bismillah. Alhamdulillah aplikasinya bermanfaa...      5             38
# 4998  bagus.. dokter sangat perhatian bahkan sampai ...      5              0
# 4999  dokternnya berbeda² ada yang ramah dan ada yg ...      5              0
#
#      reviewCreatedVersion                  at  \
# 0                  15.801 2023-01-14 17:45:35
# 1                  15.700 2023-01-13 13:55:23
# 2                  15.801 2023-01-08 23:26:37
# 3                  15.100 2022-11-21 10:13:32
# 4                  15.100 2022-11-19 08:32:16
# ...                   ...                 ...
# 4995                5.401 2019-09-03 08:48:51
# 4996                7.140 2020-05-01 08:28:34
# 4997                6.401 2020-01-09 22:27:32
# 4998                4.200 2019-02-17 22:57:34
# 4999                6.200 2019-12-16 22:08:06
#
#                                            replyContent           repliedAt
# 0     Hai wafi izzudien! Terima kasih sudah mengguna... 2023-01-14 18:40:50
# 1     Hai Suga Dillah! Mohon maaf atas ketidaknyaman... 2023-01-13 14:34:11
# 2     Hai Syifaul Amrodi! Mohon maaf atas ketidaknya... 2023-01-08 23:31:37
# 3     Hai Ariaya Nur Anggarani! Mohon maaf atas keti... 2022-11-21 11:05:03
# 4     Hai Kuskus 01! Mohon maaf atas ketidaknyamanan... 2022-11-19 08:43:22
# ...                                                 ...                 ...
# 4995  Hai Riki Bokir! Terima kasih sudah menggunakan... 2019-09-03 09:19:06
# 4996  Hai Ika ! Terima kasih sudah menggunakan Halod... 2020-05-01 08:35:36
# 4997  Hai Dek Maya! Terima kasih sudah menggunakan H... 2020-01-10 00:40:28
# 4998  Hai Billy Andreas! Terima kasih sudah mengguna... 2019-02-17 23:50:47
# 4999  Hai Jhonatan! Terima kasih sudah menggunakan H... 2019-12-16 22:15:03
#
# [5000 rows x 10 columns]

# %%
# saving the excelsheet
df.to_excel('./static/data/excel/reviews.xlsx')

# %% [markdown]
# # **PreProcessing**

# %%
# Read Data Train & Data Test

df = pd.read_excel("./static/data/excel/reviews.xlsx")
df.dropna(inplace=True)
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#                                   reviewId              userName  \
# 0     4f9da834-8ef2-431f-9f0f-81c3457a9125         wafi izzudien
# 1     f310241e-f30b-4a27-8011-94f0ccdb4615           Suga Dillah
# 2     3c3c832d-a2e5-4b5d-b17c-621b385405b3    002 Syifaul Amrodi
# 3     44ade954-5703-45e5-9472-6675b6fb113e  Ariaya Nur Anggarani
# 4     fda13ade-581f-41af-a505-2222138ac103             Kuskus 01
# ...                                    ...                   ...
# 4995  97b97128-5c40-449c-abe0-5787175afeb0       Pengguna Google
# 4996  99362173-b500-45d1-a89c-91bad69dbdad      Ika Sanrif Migas
# 4997  9b71d94c-ac97-46cb-a3ce-bbf5a53f5eb4       Pengguna Google
# 4998  b1a82cfa-5480-4d34-bcdf-521ff72312a2       Pengguna Google
# 4999  c225f32c-5536-4732-920a-6e8ca17b0aec       Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/AD5-W...
# 1     https://play-lh.googleusercontent.com/a-/AD5-W...
# 2     https://play-lh.googleusercontent.com/a-/AD5-W...
# 3     https://play-lh.googleusercontent.com/a/AEdFTp...
# 4     https://play-lh.googleusercontent.com/a-/AD5-W...
# ...                                                 ...
# 4995  https://play-lh.googleusercontent.com/EGemoI2N...
# 4996  https://play-lh.googleusercontent.com/a-/AD5-W...
# 4997  https://play-lh.googleusercontent.com/EGemoI2N...
# 4998  https://play-lh.googleusercontent.com/EGemoI2N...
# 4999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0     Di antar banyaknya rating bintang 1, belum ten...      5             14
# 1     Sengaja daftar vaksin di halodok biar cepet. D...      1             12
# 2     Saya kesel banget sama aplikasi ini. Saya udah...      1             20
# 3     Kalau dokternya tidak standby tolong jangan di...      1             65
# 4     Hallo HALODOC. Kenapa pesanan saya tidak sampa...      3             32
# ...                                                 ...    ...            ...
# 4995  sangat suka sekali dgn aplikasi ini,, dokterny...      5              0
# 4996  Penjelasan yg sangat bagus, sangat membantu sa...      5              0
# 4997  Bismillah. Alhamdulillah aplikasinya bermanfaa...      5             38
# 4998  bagus.. dokter sangat perhatian bahkan sampai ...      5              0
# 4999  dokternnya berbeda² ada yang ramah dan ada yg ...      5              0
#
#       reviewCreatedVersion                  at  \
# 0                   15.801 2023-01-14 17:45:35
# 1                   15.700 2023-01-13 13:55:23
# 2                   15.801 2023-01-08 23:26:37
# 3                   15.100 2022-11-21 10:13:32
# 4                   15.100 2022-11-19 08:32:16
# ...                    ...                 ...
# 4995                 5.401 2019-09-03 08:48:51
# 4996                 7.140 2020-05-01 08:28:34
# 4997                 6.401 2020-01-09 22:27:32
# 4998                 4.200 2019-02-17 22:57:34
# 4999                 6.200 2019-12-16 22:08:06
#
#                                            replyContent           repliedAt
# 0     Hai wafi izzudien! Terima kasih sudah mengguna... 2023-01-14 18:40:50
# 1     Hai Suga Dillah! Mohon maaf atas ketidaknyaman... 2023-01-13 14:34:11
# 2     Hai Syifaul Amrodi! Mohon maaf atas ketidaknya... 2023-01-08 23:31:37
# 3     Hai Ariaya Nur Anggarani! Mohon maaf atas keti... 2022-11-21 11:05:03
# 4     Hai Kuskus 01! Mohon maaf atas ketidaknyamanan... 2022-11-19 08:43:22
# ...                                                 ...                 ...
# 4995  Hai Riki Bokir! Terima kasih sudah menggunakan... 2019-09-03 09:19:06
# 4996  Hai Ika ! Terima kasih sudah menggunakan Halod... 2020-05-01 08:35:36
# 4997  Hai Dek Maya! Terima kasih sudah menggunakan H... 2020-01-10 00:40:28
# 4998  Hai Billy Andreas! Terima kasih sudah mengguna... 2019-02-17 23:50:47
# 4999  Hai Jhonatan! Terima kasih sudah menggunakan H... 2019-12-16 22:15:03
#
# [4540 rows x 10 columns]

# %% [markdown]
# ## Punctuation Removal
#
# Pengilangan simbol khusus seperti \r, \n, ", url, dan byte code

# %%
def cleaning(df):    
    df = re.sub(r"\n", " ",df)
    df = re.sub(r"\r", " ",df)
    df = re.sub(r"&amp;", " ",df)
    df = re.sub(r"&gt;", " ",df)
    df = re.sub(r"&lt;", " ",df)
    df = re.sub(r"&quot;", " ",df)
    df = re.sub(r"\u00a0", " ",df) 
    df = re.sub(r'''(?i)\b((?:https|http?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', "",df)
    df = re.sub(r"[-_<>*#$@()\"/%&;:<>{}`+=~|.!?,']", " ", df) #hapus simbol
    df = re.sub(r"[^a-zA-Z]", " ",df) # menghilangkan angka
    df = re.sub("\s\s+", " ",df) # menghilangkan double spasi
    return df

# %% [markdown]
# ## Word Normalization

# %%
kamus_normal = pd.read_excel("./static/data/excel/normalisasi.xlsx",header=None,names=["non-standard word","standard word"])
kamus_normal
# Out:
#        non-standard word  standard word
# NaN    non-standard word  standard word
# 0.0                 enkk           enak
# 1.0                  enk           enak
# 2.0                 guee           saya
# 3.0           holygraill        favorit
# ...                  ...            ...
# 383.0           licinnnn          licin
# 384.0             risihh          risih
# 385.0           ngalamin      mengalami
# 386.0            awalnha        awalnya
# 387.0                 tf       transfer
#
# [389 rows x 2 columns]

# %%
nonstdword = kamus_normal['non-standard word'].values.tolist()
stdword = kamus_normal['standard word'].values.tolist()

# %%
def normalize_text(text, stdword_, nonstdword_):
    text = text.split(" ")
    for i in range(len(text)):
        if text[i] in nonstdword_:
            index = nonstdword_.index(text[i])
            text[i] = stdword_[index]
    return ' '.join(map(str, text))

def normalizeData(data, stdword_, nonstdword_):
    data = data.map(lambda com : normalize_text(com,stdword_,nonstdword_))
    return data

# %% [markdown]
# ## Meaningless Removal

# %%
meaningless = pd.read_excel("./static/data/excel/meaningless.xlsx",names=['stopword'])
meaningless
# Out:
#       stopword
# 0        kamu
# 1         aduh
# 2           ah
# 3       ahelah
# 4          amp
# ..         ...
# 137        tho
# 138   carefour
# 139  carrefour
# 140      hihii
# 141   booookkk
#
# [142 rows x 1 columns]

# %%
def removeMeaningless(data):
    meaningless = pd.read_excel("./static/data/excel/meaningless.xlsx",header=None,names=['stopword'])
    meaningless = meaningless['stopword'].tolist()
    for word in meaningless:
        data = re.sub(r"\b" + word + r"\b" , " ",data)
    return data

# %% [markdown]
# ## Stopword Removal (Sastrawi)

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
stop_words = StopWordRemoverFactory().get_stop_words() # kata-kata stopword sastrawi indonesia

# %%
def removeStopword(df,stop_words_):
    for stop_word in stop_words_:
        regex_stopword = r"\b" + stop_word + r"\b"
        df = df.str.replace(regex_stopword, '')
        # df = re.sub("\s+", " ",df)
    return df

# %% [markdown]
# ## Stemming (Sastrawi)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
stemmerID = StemmerFactory().create_stemmer() # sastrawi

# %%
def stemming(text, stemmer_id):
    text_split = text.split(" ")
    stemmed_list = []
    for i in text_split:
        stemmed_list.append(stemmer_id.stem(i))
    stemmed = ' '.join(map(str,stemmed_list))
    return stemmed

def stemData(data, stemmer_id):
    data = data.map(lambda com : stemming(com,stemmer_id))
    # data = re.sub("\s\s+", " ",data)
    return data

# %% [markdown]
# ## Preprocessing

# %%
import re
def preprocessing(df):
    df['cleaning'] = df['content'].apply(cleaning)
    df['case_folding'] = df['cleaning'].apply((str.lower))
    df['normalize'] = normalizeData(df['case_folding'], stdword, nonstdword)
    df['meaningless_removal'] = df['normalize'].apply(removeMeaningless)
    df['remove_stopword'] = removeStopword(df['meaningless_removal'], stop_words).apply(cleaning)  # no stemming, stopword
    df['stemming'] = stemData(df['remove_stopword'], stemmerID)
    df['after_preprocessing'] = df['stemming']
    return df

df = preprocessing(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15984/2161419032.py in <module>
#       9     return df
#      10
# ---> 11 df = preprocessing(df)
#      12 df['after_preprocessing'] = df['stemming']
#
# ~\AppData\Local\Temp/ipykernel_15984/2161419032.py in preprocessing(df)
#       4     df['case_folding'] = df['cleaning'].apply((str.lower))
#       5     df['normalize'] = normalizeData(df['case_folding'], stdword, nonstdword)
# ----> 6     df['meaningless_removal'] = df['normalize'].apply(removeMeaningless)
#       7     df['remove_stopword'] = removeStopword(df['meaningless_removal'], stop_words).apply(cleaning)  # no stemming, stopword
#       8     df['stemming'] = stemData(df['remove_stopword'], stemmerID)
#
# ~\miniconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\miniconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\miniconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_15984/3887499941.py in removeMeaningless(data)
#       1 def removeMeaningless(data):
# ----> 2     meaningless = pd.read_excel("meaningless.xlsx",header=None,names=['stopword'])
#       3     meaningless = meaningless['stopword'].tolist()
#       4     for word in meaningless:
#       5         data = re.sub(r"\b" + word + r"\b" , " ",data)
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1231         self.storage_options = storage_options
#    1232
# -> 1233         self._reader = self._engines[engine](self._io, storage_options=storage_options)
#    1234
#    1235     def __fspath__(self):
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_openpyxl.py in __init__(self, filepath_or_buffer, storage_options)
#     520         """
#     521         import_optional_dependency("openpyxl")
# --> 522         super().__init__(filepath_or_buffer, storage_options=storage_options)
#     523
#     524     @property
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer, storage_options)
#     418             self.handles.handle.seek(0)
#     419             try:
# --> 420                 self.book = self.load_workbook(self.handles.handle)
#     421             except Exception:
#     422                 self.close()
#
# ~\miniconda3\lib\site-packages\pandas\io\excel\_openpyxl.py in load_workbook(self, filepath_or_buffer)
#     531         from openpyxl import load_workbook
#     532
# --> 533         return load_workbook(
#     534             filepath_or_buffer, read_only=True, data_only=True, keep_links=False
#     535         )
#
# ~\miniconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
# --> 317     reader.read()
#     318     return reader.wb
#
# ~\miniconda3\lib\site-packages\openpyxl\reader\excel.py in read(self)
#     276         self.read_manifest()
#     277         self.read_strings()
# --> 278         self.read_workbook()
#     279         self.read_properties()
#     280         self.read_theme()
#
# ~\miniconda3\lib\site-packages\openpyxl\reader\excel.py in read_workbook(self)
#     148         wb_part = _find_workbook_part(self.package)
#     149         self.parser = WorkbookParser(self.archive, wb_part.PartName[1:], keep_links=self.keep_links)
# --> 150         self.parser.parse()
#     151         wb = self.parser.wb
#     152         wb._sheets = []
#
# ~\miniconda3\lib\site-packages\openpyxl\reader\workbook.py in parse(self)
#      46     def parse(self):
#      47         src = self.archive.read(self.workbook_part_name)
# ---> 48         node = fromstring(src)
#      49         package = WorkbookPackage.from_tree(node)
#      50         if package.properties.date1904:
#
# KeyboardInterrupt:

# %%
# saving the excelsheet
df.to_excel('./static/data/excel/after_preprocessing.xlsx')

# %% [markdown]
# ## Labelling

# %%
service = ['mudah', 'cepat', 'lama', 'efisien', 'bagus', 'mantap', 'bantu', 'keren', 'baik', 'error', 'waktu', 'aman', 'lancar', 'guna', 'nyaman']
doctor = ['ramah', 'konsul', 'responsif', 'diagnogsa', 'komunikatif', 'respon', 'tepat', 'chat', 'spesialis', 'akurat', 'keluhan', 'pasien', 'temu', 'tanya']
medicine = ['resep', 'beli', 'sakit', 'pesan', 'cocok', 'apotek', 'klinik', 'sembuh', 'antar', 'kirim', 'butuh', 'sesuai']
fee = ['mahal', 'murah', 'terjangkau', 'transaksi', 'hemat', 'refund', 'diskon', 'minim', 'mampu', 'besar', 'bayar', 'promo']

def labelling(data):
    data.reset_index(inplace=True)
    service_=[]
    doctor_ = []
    medicine_ = []
    fee_ = []

    for i in range(len(data['after_preprocessing'])):
        if any(e_service in data.get('after_preprocessing').get(i) for e_service in service):
            if data['score'][i] < 3:
                service_.append(-1)
            elif data['score'][i] > 3:
                service_.append(1)
            else:
                service_.append(0)
        else:
            service_.append(0)

        if any(e_doctor in data.get('after_preprocessing').get(i) for e_doctor in doctor):
            if data['score'][i] < 3:
                doctor_.append(-1)
            elif data['score'][i] > 3:
                doctor_.append(1)
            else:
                doctor_.append(0)
        else:
            doctor_.append(0)

        if any(e_medicine in data.get('after_preprocessing').get(i) for e_medicine in medicine):
            if data['score'][i] < 3:
                medicine_.append(-1)
            elif data['score'][i] > 3:
                medicine_.append(1)
            else:
                medicine_.append(0)
        else:
            medicine_.append(0)

        if any(e_fee in data.get('after_preprocessing').get(i) for e_fee in fee):
            if data['score'][i] < 3:
                fee_.append(-1)
            elif data['score'][i] > 3:
                fee_.append(1)
            else:
                fee_.append(0)
        else:
            fee_.append(0)

    if "service" in data.columns:
        data = data.drop(columns=["service"])
    data.insert(0, "service", service_)
    if "doctor" in data.columns:
        data = data.drop(columns=["doctor"])
    data.insert(0, "doctor", doctor_)
    if "medicine" in data.columns:
        data = data.drop(columns=["medicine"])
    data.insert(0, "medicine", medicine_)
    if "fee" in data.columns:
        data = data.drop(columns=["fee"])
    data.insert(0, "fee", fee_)
    data = data.dropna()
    data = data.drop(data[(data['service'] == 0) & (data['doctor'] == 0) & (data['medicine'] == 0) & (data['fee'] == 0)].index)
    return data


df = labelling(df)
df.head()
# Out:
#    fee  medicine  doctor  service  level_0  index  \
# 0    0         1       0        1        0      0
# 1    0         0       0       -1        1      1
# 2   -1         0      -1       -1        2      2
# 3   -1         0       0        0        3      3
# 5   -1        -1       0       -1        5      5
#
#                                reviewId              userName  \
# 0  4f9da834-8ef2-431f-9f0f-81c3457a9125         wafi izzudien
# 1  f310241e-f30b-4a27-8011-94f0ccdb4615           Suga Dillah
# 2  3c3c832d-a2e5-4b5d-b17c-621b385405b3    002 Syifaul Amrodi
# 3  44ade954-5703-45e5-9472-6675b6fb113e  Ariaya Nur Anggarani
# 5  97835135-8c26-44a4-af0f-5c35042998d3             pras dika
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1  https://play-lh.googleusercontent.com/a-/AD5-W...
# 2  https://play-lh.googleusercontent.com/a-/AD5-W...
# 3  https://play-lh.googleusercontent.com/a/AEdFTp...
# 5  https://play-lh.googleusercontent.com/a-/AD5-W...
#
#                                              content  ...                  at  \
# 0  Di antar banyaknya rating bintang 1, belum ten...  ... 2023-01-14 17:45:35
# 1  Sengaja daftar vaksin di halodok biar cepet. D...  ... 2023-01-13 13:55:23
# 2  Saya kesel banget sama aplikasi ini. Saya udah...  ... 2023-01-08 23:26:37
# 3  Kalau dokternya tidak standby tolong jangan di...  ... 2022-11-21 10:13:32
# 5  Tidak synergy antar aplikasi seperti gojek seh...  ... 2022-12-25 17:17:31
#
#                                         replyContent           repliedAt  \
# 0  Hai wafi izzudien! Terima kasih sudah mengguna... 2023-01-14 18:40:50
# 1  Hai Suga Dillah! Mohon maaf atas ketidaknyaman... 2023-01-13 14:34:11
# 2  Hai Syifaul Amrodi! Mohon maaf atas ketidaknya... 2023-01-08 23:31:37
# 3  Hai Ariaya Nur Anggarani! Mohon maaf atas keti... 2022-11-21 11:05:03
# 5  Hai pras dika! Mohon maaf atas ketidaknyamanan... 2022-12-25 17:23:37
#
#                                             cleaning  \
# 0  Di antar banyaknya rating bintang belum tentu ...
# 1  Sengaja daftar vaksin di halodok biar cepet Di...
# 2  Saya kesel banget sama aplikasi ini Saya udah ...
# 3  Kalau dokternya tidak standby tolong jangan di...
# 5  Tidak synergy antar aplikasi seperti gojek seh...
#
#                                         case_folding  \
# 0  di antar banyaknya rating bintang belum tentu ...
# 1  sengaja daftar vaksin di halodok biar cepet di...
# 2  saya kesel banget sama aplikasi ini saya udah ...
# 3  kalau dokternya tidak standby tolong jangan di...
# 5  tidak synergy antar aplikasi seperti gojek seh...
#
#                                            normalize  \
# 0  di antar banyaknya rating bintang belum tentu ...
# 1  sengaja daftar vaksin di halodok agar cepat di...
# 2  saya kesel banget sama aplikasi ini saya sudah...
# 3  kalau dokternya tidak standby tolong jangan di...
# 5  tidak synergy antar aplikasi seperti gojek seh...
#
#                                  meaningless_removal  \
# 0  di antar banyaknya rating bintang belum tentu ...
# 1  sengaja daftar vaksin di halodok agar cepat di...
# 2  saya kesel banget sama aplikasi ini saya sudah...
# 3  kalau dokternya tidak standby tolong jangan di...
# 5  tidak synergy antar aplikasi seperti gojek seh...
#
#                                      remove_stopword  \
# 0   antar banyaknya rating bintang aplikasi jelek...
# 1  sengaja daftar vaksin halodok cepat dibilang d...
# 2   kesel banget sama aplikasi keluarin uang pas ...
# 3  kalau dokternya standby jangan ditampilkan kir...
# 5   synergy antar aplikasi gojek pelanggan pesan ...
#
#                                             stemming  \
# 0   antar banyak rating bintang aplikasi jelek la...
# 1  sengaja daftar vaksin halodok cepat bilang dat...
# 2   kesel banget sama aplikasi keluarin uang pas ...
# 3  kalau dokter standby jangan tampil kira kalau ...
# 5   synergy antar aplikasi gojek langgan pesan ap...
#
#                                  after_preprocessing
# 0   antar banyak rating bintang aplikasi jelek la...
# 1  sengaja daftar vaksin halodok cepat bilang dat...
# 2   kesel banget sama aplikasi keluarin uang pas ...
# 3  kalau dokter standby jangan tampil kira kalau ...
# 5   synergy antar aplikasi gojek langgan pesan ap...
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Save Data After PreProcessing

# %%
df.to_excel("./static/data/excel/after_labelling.xlsx")

# %% [markdown]
# # **Feature Extraction**

# %% [markdown]
# ## Read Data

# %%
import pandas as pd
df = pd.read_excel("./static/data/excel/after_labelling.xlsx")

# %% [markdown]
# ## Split Data Train (80%) & Data Test (20%)

# %%
from sklearn.model_selection import train_test_split
def splitTrainTest(df):
#     change train test size
    X_train, X_test, y_train, y_test = train_test_split(df['content'], df[['service','doctor','medicine','fee', 'after_preprocessing']], test_size=0.1)

    data_train = y_train.copy() 
    data_train = data_train.join(X_train)

    data_test = y_test.copy() 
    data_test = data_test.join(X_test)

    return data_train, data_test

# %%
data_train, data_test = splitTrainTest(df)

# %%
data_train
# Out:
#       service  doctor  medicine  fee  \
# 3983        1       1         1    0
# 2565        1       1         1    0
# 3996        1       0         1    0
# 178        -1      -1        -1    0
# 1474        1       1         0    0
# ...       ...     ...       ...  ...
# 3527        1       1         0    0
# 1450        1       0         1    1
# 1250       -1      -1        -1    0
# 996         1       0         1    0
# 1315        1       0         0    0
#
#                                     after_preprocessing  \
# 3983  aplikasi sangat bantu punya saran tambah fitur...
# 2565  apk sangat bagus dokter ramah baik cepat respo...
# 3996  rekomended dokter asyik consultasi putri intan...
# 178   tengah jam pasti pesan driver hubung chat bala...
# 1474  trimakasih halodoc saran sangat puas guna apli...
# ...                                                 ...
# 3527  keren banget ada aplikasi sangat bantu jadi pe...
# 1450  terima kasih aplikasi halodoc antar obat sanga...
# 1250  aplikasi jengkel koordinasi baik operator halo...
# 996   aplikasi sangat bantu periksa dokter stock oba...
# 1315  kecewa masa baru download terus verifikasi nom...
#
#                                                 content
# 3983  Aplikasi sudah sangat membantu. Saya punya sar...
# 2565  Apk yang sangat bagus, dokternya juga ramah ba...
# 3996  rekomended, dokternya asyik untuk consultasi.....
# 178   Setengah jam tidak ada kepastian pesanan, driv...
# 1474  Trimakasih halodoc untuk sarannya, saya sangat...
# ...                                                 ...
# 3527  Keren bgt... Dgn adanya aplikasi ini sangat me...
# 1450  terima kasih aplikasi halodoc pengantaran obat...
# 1250  Aplikasi menjengkelkan.. tidak ada koordinasi ...
# 996   Aplikasi yg sangat membantu, saat periksa ke d...
# 1315  Kecewa. Masa baru aja download terus verifikas...
#
# [3764 rows x 6 columns]

# %%
data_test
# Out:
#       service  doctor  medicine  fee  \
# 2693        1       1         1    0
# 3917        1       0         1    0
# 2843        1       1         0    0
# 3289        1       1         0    0
# 3425        1       1         0    0
# ...       ...     ...       ...  ...
# 1300        1       0         1    0
# 4110        1       1         1    0
# 1089        1       1         1    0
# 294         1       0         0    0
# 3079        1       1         1    0
#
#                                     after_preprocessing  \
# 2693  terimaksih halodoc sangat bantu hadap sakit de...
# 3917  sangat batu sekali baik pantau pesan obat bawa...
# 2843  senang ada aplikasi gin mudah tetap sehat kons...
# 3289  docter sangat ramah respon cepat tanggap sanga...
# 3425  aplikasi luar biasa sangat bantu apa jam berpa...
# ...                                                 ...
# 1300   urgent sangat bantu cepat kirim biaya selalu ...
# 4110  alhamdulillah aplikasi halodoc sangat bantu ko...
# 1089  mantab aplikasi sangat bantu sekali mudah cek ...
# 294   dokter kompeten aplikasi mudah hubung langsung...
# 3079  aplikasi bagus langsung chat dokter antri klin...
#
#                                                 content
# 2693  Terimaksih halodoc, sangat membantu saya dalam...
# 3917  sangat membatu sekali,tapi nanti diperbaiki la...
# 2843  Senang deh, adanya aplikasi kayak gini bisa me...
# 3289  Docter nya sangat ramah, Respon nya cepat tang...
# 3425  Aplikasi luar biasa sangat membantu di saat ap...
# ...                                                 ...
# 1300  Saat urgent sangat membantu dengan cepat pengi...
# 4110  Alhamdulillah ada aplikasi halodoc, sangat mem...
# 1089  Mantab aplikasi nya sangat membantu sekali,mem...
# 294   Dokternya kompeten. Aplikasinya mudah. Bisa te...
# 3079  Aplikasi yg bagus bisa langsung chat dg dokter...
#
# [419 rows x 6 columns]

# %% [markdown]
# ## TF-RF

# %%
import numpy as np

def tfrf(data_train, data_test):
    data_train.dropna(inplace=True)
    data_test.dropna(inplace=True)
    X_train, X_test, y_train, y_test = data_train['after_preprocessing'] , data_test['after_preprocessing'], data_train[['service','doctor','medicine','fee']] , data_test[['service','doctor','medicine','fee']]
    
    
    len_X_train = len(X_train)
    len_X_test = len(X_test)
    sentences = data_train['after_preprocessing'].append(data_test['after_preprocessing'])    
    # Initialize dictionary to store the overall token counts
    overall_token_counts = {}

    # Loop through each sentence
    for sentence in sentences:
        # Tokenize the sentence
        tokens = sentence.split()

        # Count the number of occurrences of each token
        token_counts = {token: tokens.count(token) for token in set(tokens)}

        # Add the token counts to the overall counts
        for token, count in token_counts.items():
            if token in overall_token_counts:
                overall_token_counts[token] += count
            else:
                overall_token_counts[token] = count

    # Create a list of all tokens
    all_tokens = list(overall_token_counts.keys())

    # Create a matrix of zeroes with dimensions of sentences and tokens
    matrix = np.zeros((len(sentences), len(all_tokens)))

    # Loop through each sentence
    for i, sentence in enumerate(sentences):
        # Tokenize the sentence
        tokens = sentence.split()
        # Calculate the relative frequency of each token
        total_tokens = len(tokens)
        token_rf = {token: tokens.count(token)/total_tokens for token in set(tokens)}
        # Add the relative frequency to the matrix
        for j, token in enumerate(all_tokens):
            if token in token_rf:
                matrix[i, j] = token_rf[token]
                
    X_train = matrix[:len_X_train]
    X_test = matrix[len_X_train:]
    
    return X_train, X_test, y_train, y_test

# %%
X_train_rf, X_test_rf, y_train_rf, y_test_rf = tfrf(data_train, data_test)

# %%
print(X_train_rf.shape)
# Out:
# (3764, 5124)

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def tfidf(data_train, data_test):
    data_train.dropna(inplace=True)
    data_test.dropna(inplace=True)
    X_train, X_test, y_train, y_test = data_train['after_preprocessing'] , data_test['after_preprocessing'], data_train[['service','doctor','medicine','fee']] , data_test[['service','doctor','medicine','fee']]
    vectorizer = TfidfVectorizer()
    X_train = vectorizer.fit_transform(X_train).toarray()
    X_test = vectorizer.transform(X_test).toarray()
    
    return X_train, X_test, y_train, y_test

# %%
X_train_idf, X_test_idf, y_train_idf, y_test_idf = tfidf(data_train, data_test)

# %%
print(X_train_idf.shape)
# Out:
# (3764, 4815)

# %% [markdown]
# # **Classification**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multioutput import MultiOutputClassifier
def classification(X_train, X_test, y_train, y_test, k):
    clf = MultiOutputClassifier(KNeighborsClassifier(n_neighbors=k))
    clf.fit(X_train, y_train)

    pred = clf.predict(X_train) # predict data train
    y_pred = clf.predict(X_test) # predict data test
    
    return X_train, X_test, y_train, y_test, y_pred, pred, clf

# %%
import numpy as np
def accuracy(y_test, y_pred):
    miss_pred = np.sum(np.not_equal(np.array(y_test), np.array(y_pred)))/float(y_test.size)
    accuracy = 1-miss_pred
    return round((accuracy * 100),2)

# %%
from sklearn.metrics import f1_score
def F1Score(y_test, y_pred):
    price = f1_score(y_test['service'], y_pred[:,0], average='macro')
    pack = f1_score(y_test['doctor'], y_pred[:,1], average='macro')
    prod = f1_score(y_test['medicine'], y_pred[:,2], average='macro')
    aroma = f1_score(y_test['fee'], y_pred[:,3], average='macro')
    average = (price + pack + prod + aroma) / 4
    return round((average * 100),2)

# %%
from sklearn.metrics import precision_score
def precisionScore(y_test, y_pred):
    price = precision_score(y_test['service'], y_pred[:,0], average='macro')
    pack = precision_score(y_test['doctor'], y_pred[:,1], average='macro')
    prod = precision_score(y_test['medicine'], y_pred[:,2], average='macro')
    aroma = precision_score(y_test['fee'], y_pred[:,3], average='macro')
    average = (price + pack + prod + aroma) / 4
    return round((average * 100),2)

# %%
from sklearn.metrics import recall_score
def recallScore(y_test, y_pred):
    price = recall_score(y_test['service'], y_pred[:,0], average='macro')
    pack = recall_score(y_test['doctor'], y_pred[:,1], average='macro')
    prod = recall_score(y_test['medicine'], y_pred[:,2], average='macro')
    aroma = recall_score(y_test['fee'], y_pred[:,3], average='macro')
    average = (price + pack + prod + aroma) / 4
    return round((average * 100),2)

# %%
def findBestK(X_train, X_test, y_train, y_test):
    bestK=1
    bestAccuracy=0
    for i in range(1,20,2):
        X_train_, X_test_, y_train_, y_test_, y_pred, pred, clf = classification(X_train, X_test, y_train, y_test, i)
        if accuracy(y_test_, y_pred) > bestAccuracy:
            bestAccuracy = accuracy(y_test_, y_pred)
            bestK = i
    return bestK

# %%
bestK_rf = findBestK(X_train_rf, X_test_rf, y_train_rf, y_test_rf)
print(f'best k of tf-rf is: {bestK_rf}')
bestK_idf = findBestK(X_train_idf, X_test_idf, y_train_idf, y_test_idf)
print(f'best k of tf-idf is: {bestK_idf}')
# Out:
# best k of tf-rf is: 7
# best k of tf-idf is: 11

# %% [markdown]
# ### Report

# %%
import json
from IPython.display import Image
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix

def createReport(X_train, X_test, y_train, y_test, bestK, tf):
    X_train_, X_test_, y_train_, y_test_, y_pred, pred, clf = classification(X_train, X_test, y_train, y_test, bestK)
    print('accuracy: ', accuracy(y_test_, y_pred))
    print('F1Score: ', F1Score(y_test_, y_pred))
    print('precisionScore: ', precisionScore(y_test_, y_pred))
    print('recallScore: ', recallScore(y_test_, y_pred))
    
    report = {
        "k": bestK
        "accuracy":accuracy(y_test_, y_pred),
        "f1_score":F1Score(y_test_, y_pred),
        "precision_score":precisionScore(y_test_, y_pred),
        "recall_score":recallScore(y_test_, y_pred)
    }
    
    with open(f'report_{tf}.json', "w") as outfile:
        json.dump(report, outfile)
        
    #Service
    cm_service = ConfusionMatrixDisplay(confusion_matrix(y_test_['service'], y_pred[:,0]), display_labels = ["negatif", "netral", "positif"])
    cm_service.plot()
    cm_service.figure_.savefig(f'./static/data/img/confusion_matrix_service_{tf}.png')
    print(f'Confusion Matrix Service {tf}')
    Image(f'./static/data/img/confusion_matrix_service_{tf}.png')
    
    report_service = classification_report(y_test_['service'], y_pred[:,0],digits=4, output_dict=True)
    df = pd.DataFrame(report_service).transpose()
    df.to_excel(f'./static/data/excel/classification_report_service_{tf}.xlsx')
    print(f'Classification Report Service {tf}')
    print(report_service)

    #Doctor
    cm_doctor = ConfusionMatrixDisplay(confusion_matrix(y_test_['doctor'], y_pred[:,1]), display_labels = ["negatif", "netral", "positif"])
    cm_doctor.plot()
    cm_doctor.figure_.savefig(f'./static/data/img/confusion_matrix_doctor_{tf}.png')
    print(f'Confusion Matrix Doctor {tf}')
    Image(f'./static/data/img/confusion_matrix_doctor_{tf}.png')
    
    report_doctor = classification_report(y_test_['doctor'], y_pred[:,1],digits=4, output_dict=True)
    df = pd.DataFrame(report_doctor).transpose()
    df.to_excel(f'./static/data/excel/classification_report_doctor_{tf}.xlsx')
    print(f'Classification Report Doctor {tf}')
    print(report_doctor)
    
    #Medicine
    cm_medicine = ConfusionMatrixDisplay(confusion_matrix(y_test_['medicine'], y_pred[:,2]), display_labels = ["negatif", "netral", "positif"])
    cm_medicine.plot()
    cm_medicine.figure_.savefig(f'./static/data/img/./static/data/img/confusion_matrix_medicine_{tf}.png')
    print(f'Confusion Matrix Medicine {tf}')
    Image(f'./static/data/img/confusion_matrix_medicine_{tf}.png')

    report_medicine = classification_report(y_test_['medicine'], y_pred[:,2],digits=4, output_dict=True)
    df = pd.DataFrame(report_medicine).transpose()
    df.to_excel(f'./static/data/excel/classification_report_medicine_{tf}.xlsx')
    print(f'Classification Report Medicine {tf}')
    print(report_medicine)
    
    #Fee
    cm_fee = ConfusionMatrixDisplay(confusion_matrix(y_test_['fee'], y_pred[:,3]), display_labels = ["negatif", "netral", "positif"])
    cm_fee.plot()
    cm_fee.figure_.savefig(f'./static/data/img/confusion_matrix_fee_{tf}.png')
    print(f'Confusion Matrix Fee {tf}')
    Image(f'./static/data/img/confusion_matrix_fee_{tf}.png')
    
    report_fee = classification_report(y_test_['fee'], y_pred[:,3],digits=4, output_dict=True)
    df = pd.DataFrame(report_fee).transpose()
    df.to_excel(f'./static/data/excel/classification_report_fee_{tf}.xlsx')
    print(f'Classification Report Fee {tf}')
    print(report_fee)
    
    print('accuracy train', accuracy(y_train_, pred))
    
    
    pred_data_train = data_train.assign(service_pred = pred[:,0], doctor_pred = pred[:, 1], medicine_pred = pred[:, 2], fee_pred = pred[:, 3] )
    pred_data_train.to_excel(f'./static/data/excel/prediction_result_train_{tf}.xlsx')
    pred_data_test = data_test.assign(service_pred = y_pred[:, 0], doctor_pred = y_pred[:, 1], medicine_pred = y_pred[:, 2], fee_pred = y_pred[:, 3] )
    pred_data_test.to_excel(f'./static/data/excel/prediction_result_test_{tf}.xlsx')
    df = pred_data_train.append(pred_data_test)
    df.to_excel(f'./static/data/excel/prediction_result_{tf}.xlsx')

# %%
# Report RF
createReport(X_train_rf, X_test_rf, y_train_rf, y_test_rf, bestK_rf, 'rf')
# Out:
# accuracy:  75.89
# F1Score:  58.29
# precisionScore:  62.44
# recallScore:  60.53
# Confusion Matrix Service rf
# Classification Report Service rf
# {'-1': {'precision': 0.3829787234042553, 'recall': 0.5294117647058824, 'f1-score': 0.4444444444444445, 'support': 34}, '0': {'precision': 0.4, 'recall': 0.03508771929824561, 'f1-score': 0.06451612903225806, 'support': 57}, '1': {'precision': 0.8692098092643051, 'recall': 0.9725609756097561, 'f1-score': 0.9179856115107913, 'support': 328}, 'accuracy': 0.8090692124105012, 'macro avg': {'precision': 0.5507295108895202, 'recall': 0.5123534865379614, 'f1-score': 0.4756487283291646, 'support': 419}, 'weighted avg': {'precision': 0.7659238521108277, 'recall': 0.8090692124105012, 'f1-score': 0.7634553962804042, 'support': 419}}
# Confusion Matrix Doctor rf
# Classification Report Doctor rf
# {'-1': {'precision': 0.47058823529411764, 'recall': 0.5714285714285714, 'f1-score': 0.5161290322580646, 'support': 28}, '0': {'precision': 0.9032258064516129, 'recall': 0.4692737430167598, 'f1-score': 0.6176470588235293, 'support': 179}, '1': {'precision': 0.6883561643835616, 'recall': 0.9481132075471698, 'f1-score': 0.7976190476190476, 'support': 212}, 'accuracy': 0.7183770883054893, 'macro avg': {'precision': 0.6873900687097642, 'recall': 0.6629385073308337, 'f1-score': 0.6437983795668805, 'support': 419}, 'weighted avg': {'precision': 0.7655976057097591, 'recall': 0.7183770883054893, 'f1-score': 0.7019228509018511, 'support': 419}}
# Confusion Matrix Medicine rf
# Classification Report Medicine rf
# {'-1': {'precision': 0.38235294117647056, 'recall': 0.4642857142857143, 'f1-score': 0.41935483870967744, 'support': 28}, '0': {'precision': 0.9135802469135802, 'recall': 0.5714285714285714, 'f1-score': 0.7030878859857482, 'support': 259}, '1': {'precision': 0.5112107623318386, 'recall': 0.8636363636363636, 'f1-score': 0.6422535211267606, 'support': 132}, 'accuracy': 0.6563245823389021, 'macro avg': {'precision': 0.6023813168072966, 'recall': 0.6331168831168831, 'f1-score': 0.5882320819407287, 'support': 419}, 'weighted avg': {'precision': 0.7513197778791435, 'recall': 0.6563245823389021, 'f1-score': 0.664962202250387, 'support': 419}}
# Confusion Matrix Fee rf
# Classification Report Fee rf
# {'-1': {'precision': 0.5882352941176471, 'recall': 0.625, 'f1-score': 0.6060606060606061, 'support': 32}, '0': {'precision': 0.9027777777777778, 'recall': 0.9530791788856305, 'f1-score': 0.9272467902995721, 'support': 341}, '1': {'precision': 0.48, 'recall': 0.2608695652173913, 'f1-score': 0.33802816901408445, 'support': 46}, 'accuracy': 0.8520286396181385, 'macro avg': {'precision': 0.657004357298475, 'recall': 0.6129829147010073, 'f1-score': 0.6237785217914209, 'support': 419}, 'weighted avg': {'precision': 0.8323406960238351, 'recall': 0.8520286396181385, 'f1-score': 0.8380295719826762, 'support': 419}}
# accuracy train 79.99

# %%
# Report IDF
createReport(X_train_idf, X_test_idf, y_train_idf, y_test_idf, bestK_idf, 'idf')
# Out:
# accuracy:  79.47
# F1Score:  57.12
# precisionScore:  69.64
# recallScore:  53.86
# Confusion Matrix Service idf
# Classification Report Service idf
# {'-1': {'precision': 0.5238095238095238, 'recall': 0.3235294117647059, 'f1-score': 0.39999999999999997, 'support': 34}, '0': {'precision': 0.5833333333333334, 'recall': 0.12280701754385964, 'f1-score': 0.20289855072463764, 'support': 57}, '1': {'precision': 0.8393782383419689, 'recall': 0.9878048780487805, 'f1-score': 0.907563025210084, 'support': 328}, 'accuracy': 0.8162291169451074, 'macro avg': {'precision': 0.6488403651616087, 'recall': 0.4780471024524487, 'f1-score': 0.5034871919782405, 'support': 419}, 'weighted avg': {'precision': 0.7789393460278988, 'recall': 0.8162291169451074, 'f1-score': 0.7705152497857086, 'support': 419}}
# Confusion Matrix Doctor idf
# Classification Report Doctor idf
# {'-1': {'precision': 0.5, 'recall': 0.21428571428571427, 'f1-score': 0.3, 'support': 28}, '0': {'precision': 0.73, 'recall': 0.8156424581005587, 'f1-score': 0.7704485488126649, 'support': 179}, '1': {'precision': 0.8019323671497585, 'recall': 0.7830188679245284, 'f1-score': 0.7923627684964201, 'support': 212}, 'accuracy': 0.7589498806682577, 'macro avg': {'precision': 0.6773107890499195, 'recall': 0.6043156801036004, 'f1-score': 0.620937105769695, 'support': 419}, 'weighted avg': {'precision': 0.7510254459087083, 'recall': 0.7589498806682577, 'f1-score': 0.7500983225744823, 'support': 419}}
# Confusion Matrix Medicine idf
# Classification Report Medicine idf
# {'-1': {'precision': 0.6428571428571429, 'recall': 0.32142857142857145, 'f1-score': 0.4285714285714286, 'support': 28}, '0': {'precision': 0.7477203647416414, 'recall': 0.9498069498069498, 'f1-score': 0.8367346938775511, 'support': 259}, '1': {'precision': 0.7894736842105263, 'recall': 0.45454545454545453, 'f1-score': 0.5769230769230769, 'support': 132}, 'accuracy': 0.7517899761336515, 'macro avg': {'precision': 0.7266837306031034, 'recall': 0.5752603252603253, 'f1-score': 0.6140763997906855, 'support': 419}, 'weighted avg': {'precision': 0.7538665889829943, 'recall': 0.7517899761336515, 'f1-score': 0.7276089066065199, 'support': 419}}
# Confusion Matrix Fee idf
# Classification Report Fee idf
# {'-1': {'precision': 0.5625, 'recall': 0.28125, 'f1-score': 0.375, 'support': 32}, '0': {'precision': 0.8666666666666667, 'recall': 0.9912023460410557, 'f1-score': 0.9247606019151847, 'support': 341}, '1': {'precision': 0.7692307692307693, 'recall': 0.21739130434782608, 'f1-score': 0.3389830508474576, 'support': 46}, 'accuracy': 0.8520286396181385, 'macro avg': {'precision': 0.7327991452991452, 'recall': 0.4966145501296273, 'f1-score': 0.5462478842542141, 'support': 419}, 'weighted avg': {'precision': 0.832739734410379, 'recall': 0.8520286396181385, 'f1-score': 0.8184644047543223, 'support': 419}}
# accuracy train 80.69
